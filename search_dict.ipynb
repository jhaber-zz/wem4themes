# %%
#!/usr/bin/env python
# -*- coding: UTF-8

# %% [markdown]
# # <p style="text-align: center;"> Dictionary Exploration and Term Search with word2vec

# %% [markdown]
# <p style="text-align: left;">Charter School Identities Project<br/><br/>Creator: Jaren Haber, PhD Candidate<br/>Institution: Department of Sociology, University of California, Berkeley<br/>Date created: September 27, 2019<br/>Date last modified: September 27, 2019

# %% [markdown]
# ## Initialize Python

# %%
# Import key packages
import gensim # for word embedding models
import _pickle as cPickle # Optimized version of pickle
import gc # For managing garbage collector
from collections import Counter # For counting terms across the corpus

# Import functions from other scripts
import sys; sys.path.insert(0, "../data_management/tools/") # To load functions from files in data_management/tools
from textlist_file import write_list, load_list # For saving and loading text lists to/from file
from df_tools import check_df, convert_df, load_filtered_df, replace_df_nulls # For displaying basic DF info, storing DFs for memory efficiency, and loading a filtered DF
from quickpickle import quickpickle_dump, quickpickle_load # For quickly loading & saving pickle files in Python

# %%
# FOR CLEANING, TOKENIZING, AND STEMMING THE TEXT
from nltk import word_tokenize, sent_tokenize # widely used text tokenizer
from nltk.stem.porter import PorterStemmer # approximate but effective (and common) method of normalizing words: stems words by implementing a hierarchy of linguistic rules that transform or cut off word endings

# %%
# FOR VISUALIZATIONS
import matplotlib
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE # For visualizing word embeddings
from scipy.spatial import distance # To use cosine distances for tSNE metric

# Visualization parameters
# %pylab inline 
# %matplotlib inline
#matplotlib.style.use('white')

import seaborn as sns # To make matplotlib prettier
sns.set(style='white')
#sns.despine()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Define file paths
home = '/home/jovyan/work/'
wem_path = home + 'wem4themes/data/wem_model_300dims.bin' # path to WEM model
charter_text_path = home + 'misc_data/charters_2015.pkl' # path to charter school web text corpus
charter_corr_path = home + 'misc_data/charters_textfiltered_2015.csv' # path to charter school race/class covariates
dict_path = home + 'text_analysis/dictionary_methods/dicts/' # path to dictionary files (may not be used here)

# %%
# For counting term frequencies, load text corpus:
df = load_filtered_df(charter_text_path, ["WEBTEXT", "NCESSCH"])
df['WEBTEXT']=df['WEBTEXT'].fillna('') # turn nan to empty iterable for future convenience
# Out:
# # rows and cols:  (10965, 2)
# # duplicates by NCESSCH: 0
#
# Columns and # missing cases (if any):
# NCESSCH
# WEBTEXT

# %%
# For checking correlations of term counts with race/class covariates, load full charter data:
df_corr = load_filtered_df(charter_corr_path, [
    'white_district', 'black_district', 'asian_district', 'native_district', 'mixed_district', 'hispanic_district', 
    'white_students', 'black_students', 'asian_students', 'hispanic_students', 'native_students', 'mixed_students',
    'students_ofcolor', 'poor_students', 'ncessch'])
list(df_corr)
# Out:
# ['students_ofcolor',
#  'poor_students',
#  'white_students',
#  'black_students',
#  'asian_students',
#  'hispanic_students',
#  'native_students',
#  'mixed_students',
#  'ncessch',
#  'white_district',
#  'black_district',
#  'asian_district',
#  'native_district',
#  'mixed_district',
#  'hispanic_district']

# %% [markdown]
# ## Define helper functions

# %%
def dict_cohere(thisdict, wem_model):
    '''Computes the average cosine similarity score of terms within one dictionary with all other terms in that same dictionary,
    effectively measuring the coherence of the dictionary.
    ...question for development: does it make sense to compare the average cosine similarity score between all terms 
    in thisdict and the average cosine similarity among the total model vocabulary? (Could that be, by definition, 0?)
    
    NOTE: For an unknown reason, calling this function deletes terms from thisdict.
    
    Inputs: List of key terms, word2vec model.
    Output: Average cosine similarity score of each word with all other words in the list of key terms.'''
    
    # Initialize average distance variables:
    word_avg_dist = 0
    word_avg_dists = 0
    dict_avg_sim = 0
    all_avg_dists = 0
    model_avg_dists = 0
    
    # Compute average cosine similarity score of each word with other dict words:
    for word in thisdict:
        word_avg_dist = (wem_model.distances(word, other_words=thisdict).sum())/len(thisdict) # Total diffs of word with all other words, take average
        word_avg_dists += word_avg_dist # Add up each average distance, incrementally
    dict_avg_sim = 1 - word_avg_dists/len(thisdict) # Find average cosine similarity score by subtracting avg. distance from 1

    # For comparison, compute average cosine similarity score of each word with ALL other words in the model vocabulary:
    #for word in thisdict:
    #    all_avg_dist = (wem_model.distances(word).sum())/len(model.vocab) # Default is to compare each word with all words
    #    all_avg_dists += all_avg_dist
    #model_avg_dist = 1 - all_avg_dists/len(model.vocab) # Find average cosine similarity score by subtracting avg. distance from 1

    #print("Average cosine similarities by word for this dictionary:       \t" + str(dict_avg_dist))
    #print("Compare to avg. cosine similarities by dict words to ALL words:\t" + str(model_avg_dist))
    
    return dict_avg_sim

# %%
def expand_dict(thisdict, coredict, maxlen, wem_model):
    '''TO DO: Create function to implement random additions to core dictionary, 
    in contrast to removing least similar word vectors--as focus_dict() does.'''
    
    #code here
    
    thisdict = list(set(thisdict)) # Remove any duplicates
    
    if len(thisdict) != maxlen: # Quality check
        print("WARNING: Function produced a dictionary of length " + str(len(thisdict)) + \
              ", which is not the specified maximum dict length of " + str(maxlen))
    
    return thisdict

# %%
def focus_dict(thisdict, coredict, maxlen, wem_model):
    '''Focus thisdict by removing least similar word vectors until reaching maxlen.
    If any words from coredict get removed, compensate for fact that they will get added back in.
        
    Input: A list of terms, core terms not to remove, desired length, and word2vec model.
    Output: The input list focused down to desired length, and still containing all the core terms.'''

    core_count = 0 # Counts number of coredict terms that were removed
    extend_count = 0 # Counts number of terms removed to offset the coming boost of core terms (that were removed and will be added back in)

    while len(thisdict) > maxlen: # Narrow thisdict down to maxlen
        badvar = model.doesnt_match(thisdict) # Find least matching term
        thisdict.remove(badvar) # Remove that least focal term, to focus dict
        if badvar in coredict: # Keep track of number of core terms removed
            core_count += 1

    while extend_count < core_count: # Remove terms until length = maxlen - number of core terms removed (to offset those core terms that will be added back in later in this script)
        badvar = model.doesnt_match(thisdict) # Find least matching term
        thisdict.remove(badvar) # Remove that least focal term, to focus dict
        extend_count += 1 # Keep track of # non-core terms added
        if badvar in coredict: # Keep track of number of core terms removed
            core_count += 1
            
    for term in coredict: # Add back in any missing core terms
        if term not in thisdict and term in list(model.vocab):
            thisdict.append(term)
            
    thisdict = list(set(thisdict)) # Remove any duplicates
    
    if len(thisdict) != maxlen: # Quality check
        print("WARNING: Function produced a dictionary of length " + str(len(thisdict)) + \
              ", which is not the specified maximum dict length of " + str(maxlen))
    
    return thisdict

# %%
def display_closestwords(wem_model, word, plotnumber):
    '''Use tSNE to display a spatial map (i.e., scatterplot) of words vectors close to given word in Word2Vec model.
    Projects each word to a 2D space (a reduction from model size) and plots the position of each word with a label.
    Based on this blog: 
    https://medium.com/@aneesha/using-tsne-to-plot-a-subset-of-similar-words-from-word2vec-bb8eeaea6229)
    
    TO DO: Incorporate bold seed terms, OPTION for getting most similar words
    
    Args:
        Word2Vec model
        Input word
        Number of words to plot
    Returns:
        Visualization of relationships between given word and its closest word vectors
    '''
    
    dimensions = 300
    
    arr = np.empty((0,dimensions), dtype='f')
    word_labels = [word]

    # get close words
    close_words = wem_model.similar_by_word(word, plotnumber)
    
    # add the vector for each of the closest words to the array
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    # find tsne coords for 2 dimensions
    tsne = TSNE(n_components=2, random_state=0, metric=distance.cosine)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    
    sns.set(style='whitegrid')
    
    # display scatter plot
    fig, ax = plt.subplots(figsize=(20,20))
    ax.scatter(x_coords, y_coords, alpha=1, color='b')

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points').set_fontsize(20)
    plt.xlim(x_coords.min()+10, x_coords.max()+10)
    plt.ylim(y_coords.min()+10, y_coords.max()+10)
    plt.show()

# %% [markdown]
# ## Load word embedding model

# %%
model = gensim.models.KeyedVectors.load_word2vec_format(wem_path, binary=True) # Load word2vec model

# %%
# dictionary of words in model (may not work for old gensim)
print(len(model.vocab))
sorted(list(model.vocab)[:200])
# Out:
# 481295
# ['a',
#  'about',
#  'academic',
#  'academics',
#  'academy',
#  'activities',
#  'admissions',
#  'after',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'application',
#  'apply',
#  'april',
#  'are',
#  'arts',
#  'as',
#  'at',
#  'athletics',
#  'back',
#  'be',
#  'board',
#  'board_of_directors',
#  'by',
#  'calendar',
#  'campus',
#  'can',
#  'careers',
#  'center',
#  'charter',
#  'child',
#  'children',
#  'class',
#  'classroom',
#  'click',
#  'college',
#  'community',
#  'contact',
#  'contact_us',
#  'content',
#  'courses',
#  'curriculum',
#  'data',
#  'day',
#  'district',
#  'do',
#  'donate',
#  'dyslexia',
#  'each',
#  'education',
#  'educational',
#  'elementary',
#  'email',
#  'employment',
#  'english',
#  'enroll',
#  'enrollment',
#  'events',
#  'facebook',
#  'faculty',
#  'families',
#  'family',
#  'fax',
#  'first',
#  'for',
#  'form',
#  'forms',
#  'from',
#  'funding',
#  'grade',
#  'grades',
#  'handbook',
#  'has',
#  'have',
#  'help',
#  'her',
#  'here',
#  'high',
#  'history',
#  'home',
#  'homeschool',
#  'how',
#  'i',
#  'idea',
#  'if',
#  'in',
#  'info',
#  'information',
#  'instruction',
#  'is',
#  'it',
#  'january',
#  'june',
#  'kindergarten',
#  'leadership',
#  'learn',
#  'learning',
#  'library',
#  'life',
#  'links',
#  'login',
#  'lunch',
#  'march',
#  'math',
#  'may',
#  'me',
#  'menu',
#  'method',
#  'middle',
#  'minutes',
#  'mission',
#  'more',
#  'my',
#  'new',
#  'news',
#  'no',
#  'not',
#  'now',
#  'of',
#  'office',
#  'on',
#  'one',
#  'online',
#  'or',
#  'other',
#  'our',
#  'out',
#  'page',
#  'parent',
#  'parents',
#  'phone',
#  'photo_gallery',
#  'plan',
#  'please',
#  'pm',
#  'policies',
#  'policy',
#  'principal',
#  'problems',
#  'program',
#  'programs',
#  'public',
#  'read',
#  'reading',
#  'resources',
#  's',
#  'schedule',
#  'school',
#  'schools',
#  'science',
#  'search',
#  'service',
#  'services',
#  'she',
#  'spanish',
#  'special_education',
#  'staff',
#  'staff_directory',
#  'state',
#  'stem',
#  'student',
#  'students',
#  'success',
#  'summer',
#  'support',
#  'teacher',
#  'teachers',
#  'team',
#  'technology',
#  'that',
#  'the',
#  'their',
#  'they',
#  'this',
#  'through',
#  'time',
#  'to',
#  'up',
#  'us',
#  'useful_links',
#  'view',
#  'volunteer',
#  'was',
#  'we',
#  'website',
#  'welcome',
#  'what',
#  'when',
#  'which',
#  'who',
#  'why',
#  'will',
#  'with',
#  'work',
#  'year',
#  'you',
#  'your']

# %% [markdown]
# ## Inductive search

# %% [markdown]
# ### Inspect similar vectors

# %%
# Find the 30 words closest to test word:
test_word = "at-risk"
candidate_sims = model.most_similar(test_word, topn=30)
candidates_list = [pair[0] for pair in candidate_sims] # Convert to list for frequency search below
candidate_sims
# Out:
# [('failure_and_academically-gifted', 0.6515583992004395),
#  ('construction_management/general', 0.6038428544998169),
#  ('academically_low-achieving', 0.6014186143875122),
#  ('percentages_of_economically', 0.5981494188308716),
#  ('disenfranchised_youth', 0.5930942296981812),
#  ('at-risk_and_disadvantaged', 0.5930824279785156),
#  ('high-ability_students', 0.5911412239074707),
#  ('underachieving', 0.589192271232605),
#  ('justice-involved', 0.5887687802314758),
#  ('under-represented', 0.5879157185554504),
#  ('low-income_and_minority', 0.5879122018814087),
#  ('african-american_and_latino', 0.585237979888916),
#  ('example_the_disenfranchised', 0.5846658945083618),
#  ('out-of-school_youth', 0.5842435956001282),
#  ('high-risk', 0.5792522430419922),
#  ('high-needs', 0.5791978240013123),
#  ('low-achieving', 0.578443169593811),
#  ('better_my_life.', 0.5783981680870056),
#  ('under-resourced', 0.5779532194137573),
#  ('living_in_poverty', 0.5778278708457947),
#  ('evidence-based_approaches', 0.5777392387390137),
#  ('adjudicated_youth', 0.5761195421218872),
#  ('pregnant/parenting', 0.5755578279495239),
#  ('at-risk_adolescents', 0.5749838948249817),
#  ('intellectually_gifted', 0.5731552839279175),
#  ('low_achieving', 0.5727622509002686),
#  ('considered_at-risk', 0.5725160837173462),
#  ('youth_yaş', 0.5718940496444702),
#  ('aimed_at_achieving', 0.5704052448272705),
#  ('low\xadincome', 0.5703068375587463)]

# %%
# Repeat inductive process of exploration for a list of seed terms like:
inqseed = ['inquiry-based', 'problem-based', 'discovery-based', 'experiential', 'constructivist']

# %%
# Seed dictionary and similar terms:
model.most_similar(inqseed, topn=500)
# Out:
# [('integrated_interdisciplinary', 0.8495174646377563),
#  ('technology-infused', 0.8478963375091553),
#  ('hands-on_and_minds-on', 0.845363974571228),
#  ('hands-on/minds-on', 0.8449170589447021),
#  ('project-centered', 0.8422079086303711),
#  ('discussion-based', 0.8401801586151123),
#  ('problem-based_learning', 0.8382363319396973),
#  ('experiential_approach', 0.8377059698104858),
#  ('hands-on_minds-on', 0.8366389274597168),
#  ('life-based', 0.8346015214920044),
#  ('science-driven', 0.8336309194564819),
#  ('language-rich', 0.8326779007911682),
#  ('simulations_role-playing', 0.8310806155204773),
#  ('cognitively_demanding', 0.8298742771148682),
#  ('literacy-based', 0.8274999856948853),
#  ('developmentally-based', 0.8263034820556641),
#  ('sensory-rich', 0.8242142796516418),
#  ('inquiry-driven', 0.8225501775741577),
#  ('student-driven_exploration', 0.8221181035041809),
#  ('hand-on', 0.8210930824279785),
#  ('whole-brain', 0.820958137512207),
#  ('hands‑on', 0.8192182183265686),
#  ('active_inquiry', 0.8190356492996216),
#  ('concrete_manipulative', 0.8183961510658264),
#  ('content-specific_grade-by-grade', 0.817798912525177),
#  ('design-based', 0.8177317380905151),
#  ('interdisciplinary_project-based', 0.8172607421875),
#  ('andinnovative', 0.8163930177688599),
#  ('explorative', 0.8157153129577637),
#  ('out-the-door', 0.8140756487846375),
#  ('student-centered_inquiry-based', 0.8139445781707764),
#  ('exploration_and_experimentation', 0.813693642616272),
#  ('thematic_integrated', 0.8128688335418701),
#  ('experiential_project-based', 0.8116459846496582),
#  ('seminar-based', 0.8115121126174927),
#  ('socratic', 0.8107789158821106),
#  ('experientially', 0.8106255531311035),
#  ('literature-rich', 0.8103781938552856),
#  ('interdisciplinary_and_multi-dimensional', 0.810289204120636),
#  ('interdisciplinary_explorations', 0.8100319504737854),
#  ('inter-disciplinary', 0.8097734451293945),
#  ('rigorous_skills-based', 0.809016227722168),
#  ('cross-disciplinary', 0.8088001608848572),
#  ('socratic_dialogue', 0.8087124824523926),
#  ('life-enhancing_skills', 0.8080996870994568),
#  ('discovery-based_learning', 0.807870626449585),
#  ('movement-based', 0.8067164421081543),
#  ('technology-enriched', 0.8064981698989868),
#  ('siop_sheltered', 0.8064740300178528),
#  ('child-centered_individualized', 0.8060619831085205),
#  ('child-led', 0.8060503005981445),
#  ('placed-based', 0.8053415417671204),
#  ('activity-based', 0.8051958084106445),
#  ('singapore_math®', 0.8045239448547363),
#  ('iqwst', 0.8040371537208557),
#  ('long-term_in-depth', 0.8036824464797974),
#  ('multi-modality', 0.803024411201477),
#  ('incorporating_the_principles', 0.8029565811157227),
#  ('laboratory-based', 0.8023532629013062),
#  ('standards-driven', 0.8017276525497437),
#  ('technology-rich', 0.8013660311698914),
#  ('pedagogical_approach', 0.8012879490852356),
#  ('learn-by-doing', 0.8012759685516357),
#  ('problem-centered', 0.8009319305419922),
#  ('flexible_groupings', 0.8002468943595886),
#  ('cross-curricular_project-based', 0.8001019954681396),
#  ('outside-the-box', 0.7999257445335388),
#  ('common-core_aligned', 0.799612283706665),
#  ('goal-driven', 0.7995284795761108),
#  ('constructivist-based', 0.7992847561836243),
#  ('minds-on', 0.7992053031921387),
#  ('imyc', 0.7991739511489868),
#  ('second-language_acquisition', 0.798521101474762),
#  ('child-directed', 0.7977443337440491),
#  ('in-depth_interdisciplinary', 0.7975376844406128),
#  ('skills.the', 0.7972171306610107),
#  ('interdisciplinary_units', 0.796971321105957),
#  ("'real-world", 0.7958564162254333),
#  ('inventive_thinking', 0.7957399487495422),
#  ('non-arts_objectives', 0.7956463098526001),
#  ('leading-edge', 0.7955679893493652),
#  ('literacyinstruction', 0.7953605651855469),
#  ('fused', 0.7952641248703003),
#  ('technology-rich_environment', 0.7946821451187134),
#  ('inquiry_arcs', 0.7945624589920044),
#  ('inquiry_based', 0.7940033078193665),
#  ('foss_modules', 0.7936188578605652),
#  ('knowledge-rich', 0.7934862971305847),
#  ('prbl', 0.7928091883659363),
#  ('integrated_thematic', 0.7926595211029053),
#  ('investigative_inquiry-based', 0.7926422357559204),
#  ('recursive', 0.792486310005188),
#  ('observation_and_experimentation', 0.7921679019927979),
#  ('thematically_integrated', 0.7917385101318359),
#  ('seminar-style', 0.7909433841705322),
#  ('arts-integrated', 0.790861964225769),
#  ('integrated_technology-based', 0.7899757623672485),
#  ('learning-based', 0.7897666692733765),
#  ('common_core-based', 0.7897598743438721),
#  ('engineering_is…', 0.7897204160690308),
#  ('kagan_cooperative', 0.7897151708602905),
#  ('fieldwork_and_experts', 0.7895871996879578),
#  ('provides_a_myriad', 0.7892605066299438),
#  ('discipline-based', 0.7892518043518066),
#  ('cross-curricular_approach', 0.7891045212745667),
#  ('culturally-responsive', 0.7889208197593689),
#  ('values-centered', 0.7888398170471191),
#  ('kāʻeo', 0.7880820035934448),
#  ('trans-disciplinary', 0.7875545620918274),
#  ('thoughtfully_designed', 0.7872085571289062),
#  ('backwards_design', 0.7871450185775757),
#  ('strengths-based', 0.7870912551879883),
#  ('engagestudents', 0.7868783473968506),
#  ('proven_methodology', 0.7868454456329346),
#  ('value-based', 0.7863008379936218),
#  ('unschooling_is_a_less', 0.7861228585243225),
#  ('research-backed', 0.78578782081604),
#  ('brain-based', 0.7846753001213074),
#  ('meaningful_and_memorable', 0.7842831611633301),
#  ('extended_student-influenced', 0.7839354276657104),
#  ('standards-based_data-driven', 0.7837127447128296),
#  ('sustained_inquiry', 0.7836884260177612),
#  ('interactive_multimedia', 0.7830429673194885),
#  ('pairs_pre-professional', 0.782805323600769),
#  ('teacher-student_interactions', 0.78279709815979),
#  ('culturally-based', 0.7827206254005432),
#  ('learner-centered', 0.7826879620552063),
#  ('multi-modal', 0.7825088500976562),
#  ('teacher-developed', 0.7822173237800598),
#  ('promote_multi-sensory', 0.7814486026763916),
#  ('child-initiated', 0.7812347412109375),
#  ('highly_motivational', 0.78099524974823),
#  ('includes_mini-lessons', 0.7809259295463562),
#  ('rigorous_arts-integrated', 0.7808547616004944),
#  ('integrated/interdisciplinary', 0.7807731628417969),
#  ('ecopedagogical_praxis', 0.7805423736572266),
#  ('literature-based', 0.7805274128913879),
#  ('highly_motivating', 0.780468225479126),
#  ('systematic_and_explicit', 0.7802591919898987),
#  ('inquiry-based_approach', 0.7799886465072632),
#  ('proven_methods', 0.7799583673477173),
#  ('project-oriented', 0.779927134513855),
#  ('multi-layered', 0.7797150611877441),
#  ('using_the_grr', 0.7796609401702881),
#  ('experience-based', 0.7794221639633179),
#  ('fieldwork_experts', 0.7794121503829956),
#  ('thescientific', 0.7792518138885498),
#  ('instructional_best-practices', 0.7791728973388672),
#  ('critique_and_reflection', 0.7790368795394897),
#  ('promising_pages', 0.7789380550384521),
#  ('service-based', 0.7788323760032654),
#  ('meaningful_real-life', 0.7787033319473267),
#  ('places_a_premium', 0.7785038948059082),
#  ('concept-driven', 0.7784310579299927),
#  ('research-based_teacher-tested', 0.7783926129341125),
#  ('experiential_constructivist', 0.7783170938491821),
#  ('interdisciplinary_thematic', 0.7782268524169922),
#  ('observation_questioning', 0.7781475186347961),
#  ('nuturing', 0.7778288125991821),
#  ('uses_data-based', 0.7776727676391602),
#  ('didactic_materials', 0.7773059606552124),
#  ('steam-based', 0.7771978378295898),
#  ('visually_oriented', 0.7770324945449829),
#  ('data-driven_differentiated', 0.7770164608955383),
#  ('afrikan', 0.7769458293914795),
#  ('language-rich_environment', 0.7768865823745728),
#  ('constructivist_pedagogy', 0.776795506477356),
#  ('activity-oriented', 0.776775062084198),
#  ('kinaesthetic', 0.7766175270080566),
#  ('pedagogical_principles', 0.7765884399414062),
#  ('encompass_engaging', 0.7759477496147156),
#  ('instruction_cgi', 0.775710940361023),
#  ('culturally-relevant', 0.7756189107894897),
#  ('project‐based', 0.7755494117736816),
#  ('high-engagement', 0.7754440307617188),
#  ('rotating_stations', 0.7753847241401672),
#  ('individually_paced', 0.7753292322158813),
#  ('thematic_interdisciplinary', 0.7750223278999329),
#  ('hands-on_multisensory', 0.7750028371810913),
#  ('projects-based', 0.7744399309158325),
#  ('arts-integrated_approach', 0.7744042873382568),
#  ('constructivists', 0.774383544921875),
#  ('sel-inspired', 0.7741828560829163),
#  ('facilitates_skills-based', 0.7740978598594666),
#  ('colloquia', 0.7738200426101685),
#  ('meaningful_purposeful', 0.7736301422119141),
#  ('computer-based_software', 0.7734165787696838),
#  ('learning…', 0.773362398147583),
#  ('well-designed', 0.7732540369033813),
#  ('issues-based', 0.7730090618133545),
#  ('object-oriented', 0.772854208946228),
#  ('creatinga', 0.7727165818214417),
#  ('systematic_and_cumulative', 0.7727146148681641),
#  ('learningand', 0.7723217606544495),
#  ('choice-based', 0.7722679376602173),
#  ('harkness_table', 0.7722387313842773),
#  ('integrates_them_into_a_cohesive', 0.7721678018569946),
#  ('sensory-based_learning', 0.7721182107925415),
#  ('engaging_and_stimulating', 0.7718881368637085),
#  ('experiential-based', 0.7718755006790161),
#  ('push-in_model', 0.771639347076416),
#  ('curriculum-centered', 0.7716184854507446),
#  ('ignite_curiosity', 0.7715743184089661),
#  ('nature-oriented', 0.7715632319450378),
#  ('cross-curricular', 0.7714242935180664),
#  ('interest-based', 0.7713907957077026),
#  ('scientifically-based_reading', 0.7711576223373413),
#  ('system®', 0.7710269093513489),
#  ('inquiry-based_units', 0.7709473371505737),
#  ('qcss_employs', 0.7707687020301819),
#  ('inter-grade', 0.7707219123840332),
#  ('student-centered_project-based', 0.770665168762207),
#  ('linking_outstanding', 0.7699817419052124),
#  ('combines_rigorous', 0.7698442935943604),
#  ('brain-compatible', 0.7697906494140625),
#  ('artistic_andexperiential', 0.7696584463119507),
#  ('academically-integrated', 0.7696337103843689),
#  ('language-enriched', 0.7695832252502441),
#  ('writing-centered', 0.7695285081863403),
#  ('iccp', 0.7694188356399536),
#  ('student-centric', 0.7693551778793335),
#  ('relevant_and_challenging', 0.7693057060241699),
#  ('culture-based', 0.7692346572875977),
#  ('researched-based', 0.769227147102356),
#  ('model_that_emphasizes', 0.7691826820373535),
#  ('customization_options', 0.7690641283988953),
#  ('didactic', 0.7689290046691895),
#  ('studies-based', 0.7689105868339539),
#  ('focuses_heavily', 0.7687931060791016),
#  ('incorporate_movement', 0.768683671951294),
#  ('arts-integration', 0.7686799168586731),
#  ('inter-curricular', 0.7686535120010376),
#  ('classroom-tested', 0.7685885429382324),
#  ('problem_based/project', 0.768538773059845),
#  ('student-powered', 0.7683544158935547),
#  ('inwhich', 0.7682445049285889),
#  ('team-teaching', 0.7676835060119629),
#  ('transdisciplinary_themes', 0.7676575779914856),
#  ('fosters_life-long', 0.7676243782043457),
#  ('micro-economic_ventures', 0.7675969004631042),
#  ('low-stress', 0.767544150352478),
#  ('aboard_the_biobus', 0.7674918174743652),
#  ('concrete_pictorial', 0.7674029469490051),
#  ('teaching_methodologies', 0.7672445178031921),
#  ('culturally-rich', 0.7671927213668823),
#  ('computer-enhanced', 0.7670975923538208),
#  ('highly_scripted', 0.7667850255966187),
#  ('thematic_approach', 0.7664554119110107),
#  ('dovetail', 0.7664316892623901),
#  ('moves_from_the_concrete', 0.7663434743881226),
#  ('tprs', 0.7663087844848633),
#  ('core-knowledge', 0.766232967376709),
#  ('approaches_such_as_sheltered', 0.7661843299865723),
#  ('reinforce_and_complement', 0.7661657333374023),
#  ('nature_journaling', 0.7661342620849609),
#  ('spiraled', 0.765924870967865),
#  ('choice-based_art', 0.7658894658088684),
#  ('appb_teaching', 0.7657496929168701),
#  ('practice-based', 0.7655481100082397),
#  ('content-driven', 0.7655287981033325),
#  ('environmentally-based', 0.7653433084487915),
#  ('incorporating_real-world', 0.7652419209480286),
#  ('computer-mediated', 0.7651586532592773),
#  ('every-day', 0.7651154398918152),
#  ('sustained_in-depth', 0.7649432420730591),
#  ('andservice', 0.7648242115974426),
#  ('activities/lessons', 0.7647860050201416),
#  ('internships_and_apprenticeships', 0.7647513151168823),
#  ('personlized', 0.7646218538284302),
#  ('intercultural_awareness', 0.7645338773727417),
#  ('theoretical_and_practical', 0.7644098997116089),
#  ('curriculum.our', 0.7641298770904541),
#  ('real-world_problem-solving', 0.7640814185142517),
#  ('blends_expertise', 0.7639940977096558),
#  ('multimodal', 0.763953447341919),
#  ('concrete–pictorial–abstract_learning', 0.7639374732971191),
#  ('developmentallyappropriate', 0.7639334201812744),
#  ('discovery_exploration', 0.7638082504272461),
#  ('intrinsically', 0.7637764811515808),
#  ('responsive_pedagogy', 0.7637581825256348),
#  ('inquiry_arc', 0.7637479901313782),
#  ('proven_pedagogy', 0.7637020349502563),
#  ('inquiry-rich', 0.7636933326721191),
#  ('accordance_with_the_m-dcps', 0.7636283040046692),
#  ('concept-based', 0.7635579109191895),
#  ('inherently_rigorous', 0.7635101079940796),
#  ('teaching-learning', 0.7634100914001465),
#  ('stem-based', 0.763047456741333),
#  ('synthetic_phonics', 0.7630106210708618),
#  ('carefully_sequenced', 0.7629914879798889),
#  ('marzano_strategies', 0.7628880739212036),
#  ('stem-oriented', 0.7628116011619568),
#  ('realworld_hands-on', 0.7627570033073425),
#  ('research-based_and_has_been_proven', 0.7627461552619934),
#  ('quarter-long', 0.7626131772994995),
#  ('academically_oriented', 0.7625234127044678),
#  ('solid_sequential', 0.7624523639678955),
#  ('whole-group', 0.7623269557952881),
#  ('multi-week', 0.7622964978218079),
#  ('wicor', 0.7621934413909912),
#  ('brain-friendly', 0.7621030807495117),
#  ('designing_and_facilitating', 0.7621011734008789),
#  ('enhanced_curriculum', 0.7620676755905151),
#  ('data-driven_and_student-centered', 0.7619946002960205),
#  ('blearning', 0.7619768977165222),
#  ('unique_and_engaging', 0.7619565725326538),
#  ('technology-centered', 0.7619447708129883),
#  ('simulates', 0.7618776559829712),
#  ('tcrwp', 0.7617876529693604),
#  ('way™', 0.7617628574371338),
#  ('technologies_and_our_science-based', 0.7617355585098267),
#  ('teacher-guided', 0.7617285847663879),
#  ('child-sized_furniture', 0.761690616607666),
#  ('infusion_of_flocabulary', 0.7614998817443848),
#  ('collegial_sharing', 0.7614883184432983),
#  ('technology-integrated', 0.7614085674285889),
#  ('multiple_modality', 0.7612947225570679),
#  ('nonlinguistic', 0.7612479329109192),
#  ('multi-modal_approach', 0.7611615657806396),
#  ('real-problem-oriented', 0.7611151337623596),
#  ('encouraging_an_unstructured', 0.7608652710914612),
#  ('dbae', 0.7607847452163696),
#  ('seminar/shared', 0.7607476711273193),
#  ('outcome-focused', 0.760638952255249),
#  ('inductive', 0.7604257464408875),
#  ('child-centric', 0.7603961229324341),
#  ('wida_eld', 0.7603800892829895),
#  ('relationship-based', 0.7602951526641846),
#  ('multi-disciplinary_integrated', 0.7601431012153625),
#  ('research-supported', 0.7599054574966431),
#  ('team-focused', 0.7597765922546387),
#  ('toinvestigate', 0.7597536444664001),
#  ('rigorously_researched', 0.7595143914222717),
#  ('adaptive_curriculum', 0.7594753503799438),
#  ('human-animal', 0.7594305872917175),
#  ('creativity_and_self-expression', 0.7594300508499146),
#  ('human-centered', 0.7594048976898193),
#  ('ieyc', 0.759355902671814),
#  ('systematic_and_sequential', 0.7591609954833984),
#  ('fun_with_phonograms', 0.7590970993041992),
#  ('expeditions.', 0.7590901255607605),
#  ('fostering_curiosity', 0.7590858936309814),
#  ('keyed', 0.7588655352592468),
#  ('tomlinson_mctighe', 0.7588614821434021),
#  ('cognitively_guided', 0.7588564157485962),
#  ('competency-based_progression', 0.7588304281234741),
#  ('standards-based_differentiated', 0.7587600946426392),
#  ('physically_and_intellectually', 0.7586821913719177),
#  ('direct-instruction', 0.758590579032898),
#  ('mentorships_and_workplace', 0.7585058808326721),
#  ('hands‐on', 0.7581639289855957),
#  ('two-teacher_model', 0.7581038475036621),
#  ('pop-up_micro-schools', 0.7579929232597351),
#  ('routines_and_rituals', 0.7577375173568726),
#  ('enriches_and_inspires', 0.7576797008514404),
#  ('educator-scripted', 0.7576676607131958),
#  ('feedback-rich', 0.757429301738739),
#  ('project-based', 0.7572604417800903),
#  ('foss®', 0.7572170495986938),
#  ('heterogeneous_grouping', 0.7572029829025269),
#  ('authentic_and_meaningful', 0.7571540474891663),
#  ('tends_to_emphasize', 0.7571284770965576),
#  ('adventure-based', 0.7570919394493103),
#  ('interwoven_throughout', 0.7570263147354126),
#  ('constructivism', 0.7570124268531799),
#  ('environmental_consciousness', 0.7566356658935547),
#  ('constructive_processes', 0.756443977355957),
#  ('marcy_cook', 0.7563488483428955),
#  ('self-correction', 0.7563436031341553),
#  ('scientific_exploration', 0.7563290596008301),
#  ('haumāna', 0.756321132183075),
#  ('teacher-directed_instruction', 0.7562533617019653),
#  ('instructional_stances', 0.7562111020088196),
#  ('motivating_and_engaging', 0.756206750869751),
#  ('theme-based_interdisciplinary', 0.7561931610107422),
#  ('hands-on-learning', 0.7561554908752441),
#  ('culturally-appropriate', 0.7561239004135132),
#  ('standard-based', 0.7560677528381348),
#  ('employing_a_variety', 0.7560242414474487),
#  ('child-initiated_play', 0.7560114860534668),
#  ('pbl/stem', 0.7560056447982788),
#  ('emergent_literacy', 0.7558497786521912),
#  ('integrative', 0.7557958364486694),
#  ('hwt', 0.7557465434074402),
#  ('passageworks', 0.7556788325309753),
#  ('materials_are_self-correcting', 0.7556450366973877),
#  ('multi-aged_learning', 0.7556428909301758),
#  ('non-textbook', 0.7555742263793945),
#  ('knowledge-based', 0.7555392980575562),
#  ('tfu', 0.755416989326477),
#  ('authentic_real-world', 0.7549742460250854),
#  ('integrated_child-centered', 0.7549427151679993),
#  ('multi-sensory', 0.7549135684967041),
#  ('p21_framework', 0.7548849582672119),
#  ('tactile_learners', 0.7548487186431885),
#  ('cocurricular_programs', 0.7547835111618042),
#  ('designed_to_complement', 0.7546703815460205),
#  ('differentiated_instructional', 0.7543216347694397),
#  ('gef', 0.7539509534835815),
#  ('warm/strict', 0.7539321184158325),
#  ('internal_self-discipline', 0.7539318203926086),
#  ('innovative_in-field', 0.7539230585098267),
#  ('educating_for_sustainability', 0.7538208961486816),
#  ('real-world_examples', 0.7537159323692322),
#  ('carefully_constructed', 0.75368332862854),
#  ('reflective_thinking', 0.7536682486534119),
#  ('papakū_makawalu', 0.7536284923553467),
#  ('evidenced-based', 0.7533184289932251),
#  ('awell-rounded', 0.7532795667648315),
#  ('standard-aligned', 0.7532682418823242),
#  ('observational_protocol', 0.7531938552856445),
#  ('challenge-based_learning', 0.753093421459198),
#  ('ipc_and_imyc', 0.7530875205993652),
#  ('novel-based', 0.7530409693717957),
#  ('conceptual_framework', 0.753021776676178),
#  ('structured_and_predictable', 0.7530104517936707),
#  ('lrpa_implements', 0.7528712749481201),
#  ('multi-sensory_experiences', 0.7528691291809082),
#  ('purposefully_designed', 0.7528502941131592),
#  ('multi-age_groupings', 0.7527652382850647),
#  ('cross-curricular_units', 0.7526158094406128),
#  ('innovative_student-centered', 0.7525433301925659),
#  ('orff_approach', 0.7524722814559937),
#  ('hands_on_manipulatives', 0.7524104118347168),
#  ('codes_of_cooperation', 0.7523797750473022),
#  ('implement_data-driven', 0.7523585557937622),
#  ('spiraling', 0.7523473501205444),
#  ('arts-based', 0.7522239089012146),
#  ('implements_specially', 0.7522200345993042),
#  ('compaction', 0.752216637134552),
#  ('aimed_at_promoting', 0.752212643623352),
#  ('inacademic', 0.752093493938446),
#  ('means_of_differentiating', 0.7519787549972534),
#  ('epistemology', 0.7519458532333374),
#  ('everfi', 0.7519142031669617),
#  ('joyful_and_engaging', 0.7518782615661621),
#  ('andinterests', 0.7518699169158936),
#  ('pedagogical_practices', 0.7517184019088745),
#  ('brain-based_research', 0.7517085075378418),
#  ('syem_academies', 0.7517022490501404),
#  ('complex_adult-world', 0.7516024112701416),
#  ('fundamentals_and_theories', 0.7515676021575928),
#  ('mid-coast_maine', 0.7515125274658203),
#  ('classical/stem_based', 0.7514321804046631),
#  ('humanities_and_the_sciences', 0.7513932585716248),
#  ('field-based', 0.7513605356216431),
#  ('choreograph_dances', 0.7513378858566284),
#  ('proven_methodologies', 0.7512938976287842),
#  ('emphasizes_scientific', 0.7512928247451782),
#  ('minecraftedu_is_a_specialized', 0.751270055770874),
#  ('transdisciplinary_units', 0.7512691020965576),
#  ('intellectually_stimulating', 0.7510191798210144),
#  ('-mystery_science', 0.7509757280349731),
#  ('multi-aged_grouping', 0.7509302496910095),
#  ('social-studies', 0.7508546113967896),
#  ('inquiry/research', 0.7508414387702942),
#  ('creativity_and_problem-solving', 0.7507663369178772),
#  ('trauma-sensitive', 0.7507274150848389),
#  ('mutt-i-grees', 0.7507057785987854),
#  ('paralleled', 0.7507001161575317),
#  ('constructivist_approach', 0.7505307793617249),
#  ('blended-learning_model', 0.7504773139953613),
#  ('awaken_the_imagination', 0.7504336833953857),
#  ('fosters_independence', 0.7503855228424072),
#  ('self-designed', 0.7503668665885925),
#  ('sustainability-focused', 0.7502604126930237),
#  ('fusing', 0.7501850724220276),
#  ('chard_s.c.', 0.7501236200332642),
#  ('faculty-led', 0.7500947713851929),
#  ('integrates_meaningful', 0.750085175037384),
#  ('decolonizing', 0.7500844597816467),
#  ('learner-centered_culture', 0.7500629425048828),
#  ('teacher-centered', 0.7500543594360352),
#  ('pedagogical_delivery', 0.7500061988830566),
#  ('unit-long', 0.7498350143432617),
#  ('student-based', 0.7498130798339844),
#  ('media-rich', 0.7497826814651489),
#  ('cross-discipline', 0.7497566342353821),
#  ('small-school_atmosphere', 0.7497485280036926),
#  ('role-modeling', 0.7497259378433228),
#  ('languagelearning', 0.7497036457061768),
#  ('inquiry-based_investigative', 0.7496107220649719),
#  ('planetbravo', 0.7496062517166138),
#  ('theoretical_foundations', 0.7495882511138916),
#  ('re-teaches', 0.7494917511940002),
#  ('effectiveness_of_metacognitive', 0.7494254112243652),
#  ('direct-instruction_aids', 0.7494031190872192),
#  ('isorganized', 0.7493926286697388),
#  ('s.t.e.m.', 0.7493213415145874),
#  ('synapse', 0.7492674589157104),
#  ('emotionally_responsive', 0.7491683959960938),
#  ('scaffolded', 0.7490619421005249),
#  ('invention_experimentation', 0.749053955078125),
#  ('reality-based', 0.7490456700325012),
#  ('non-institutional', 0.7490411996841431),
#  ('stimulate_critical', 0.7489989995956421),
#  ('wedo', 0.7489629983901978),
#  ('literature_scientifically', 0.7488839626312256),
#  ('creativity_and_originality', 0.7488524913787842),
#  ('tools_priceless', 0.7488275766372681)]

# %%
# Test seed terms for direct instruction (DI):
# "direct-instruction", "content-driven"
model.most_similar(["mastery-learning"], topn = 50)
# Out:
# [('career-applicable', 0.8442488312721252),
#  ('synthetic_phonics', 0.8379385471343994),
#  ('grit_and_zest', 0.8369365334510803),
#  ('systematic_and_cumulative', 0.8344263434410095),
#  ('needing_a_slower', 0.8341528177261353),
#  ('strict/warm', 0.8339699506759644),
#  ('discussion-based_assessment', 0.8327045440673828),
#  ('approaches_and_strategies', 0.8300595283508301),
#  ('hwt', 0.8285154700279236),
#  ('includes_mini-lessons', 0.8267961144447327),
#  ('research-backed', 0.8250576257705688),
#  ('tprs', 0.8237885236740112),
#  ('way™', 0.8236422538757324),
#  ('explicitly_and_systematically', 0.8233060240745544),
#  ('learn-by-doing', 0.8231520652770996),
#  ('re-engages', 0.822525680065155),
#  ('ipc_and_imyc', 0.8217571973800659),
#  ('content-specific_grade-by-grade', 0.8216098546981812),
#  ('coherent_sequenced', 0.8212858438491821),
#  ('*since', 0.8203839659690857),
#  ('retest/reassess', 0.8199358582496643),
#  ('direct-instruction', 0.8195356130599976),
#  ('mymath', 0.8194944858551025),
#  ('concept-driven', 0.8193811774253845),
#  ('rigor_and_depth', 0.8191386461257935),
#  ('student-centered_inquiry-based', 0.8188637495040894),
#  ('movement-based', 0.8187100887298584),
#  ('foss_modules', 0.8185172080993652),
#  ('systematic_and_explicit', 0.818452000617981),
#  ('multi-aged_learning', 0.8184187412261963),
#  ('intertwining', 0.8173028230667114),
#  ('tcmpc', 0.8171952962875366),
#  ('instructional_best-practices', 0.8161884546279907),
#  ('theoretical_framework', 0.8161771297454834),
#  ('componentsof', 0.8160592913627625),
#  ('incorporating_real-world', 0.8153370022773743),
#  ('concrete_manipulative', 0.8149304389953613),
#  ('expeditions—', 0.814918577671051),
#  ('fun_with_phonograms', 0.8145347833633423),
#  ('4-blocks', 0.8142393231391907),
#  ('object-oriented', 0.8142203092575073),
#  ('samsung_chromebook', 0.8142053484916687),
#  ('outside-the-box_thinking', 0.813849151134491),
#  ('multi_sensory', 0.8134316205978394),
#  ('multi-modal_approach', 0.8133341073989868),
#  ('rigorous_skills-based', 0.8132665157318115),
#  ('iqwst', 0.8131582736968994),
#  ('brainwise', 0.812670111656189),
#  ('math54', 0.8125743865966797),
#  ('persuasive/propaganda', 0.8122437000274658)]

# %%
model.similar_by_word("inquiry-based")
# Out:
# [('problem-based', 0.7188608646392822),
#  ('inquiry_based', 0.7165826559066772),
#  ('integrated_interdisciplinary', 0.7108476161956787),
#  ('literacy-based', 0.7067997455596924),
#  ('problem-based_learning', 0.705278754234314),
#  ('experiential_approach', 0.6990994215011597),
#  ('technology-infused', 0.6932752132415771),
#  ('student-driven_exploration', 0.6918015480041504),
#  ('prbl', 0.6899794340133667),
#  ('showcase_of_self-driven', 0.6882768273353577)]

# %% [markdown]
# ### Overview of search process

# %% [markdown]
# By using the model to look at similar words across terms, create a list of candidate terms for a bigger conceptual dictionary. Manually search all these candidate terms for those that are tightly conceptually related to the seed dictionary. This process blends data-driven search from the model with hand-driven search across the candidate terms.

# %%
# Find the 15 words closest to each term in seed dictionary:
for term in inqseed:
    print("\nT0P 15 WORDS CLOSEST TO " + term)
    for line in list(model.most_similar(term, topn=15)):
        print(line)

#model.most_similar("problem-based", topn=30)
# Out:
# T0P 15 WORDS CLOSEST TO inquiry-based
# ('problem-based', 0.7188608646392822)
# ('inquiry_based', 0.7165826559066772)
# ('integrated_interdisciplinary', 0.7108476161956787)
# ('literacy-based', 0.7067997455596924)
# ('problem-based_learning', 0.705278754234314)
# ('experiential_approach', 0.6990994215011597)
# ('technology-infused', 0.6932752132415771)
# ('student-driven_exploration', 0.6918015480041504)
# ('prbl', 0.6899794340133667)
# ('showcase_of_self-driven', 0.6882768273353577)
# ('hands-on_and_minds-on', 0.687936007976532)
# ('qcss_employs', 0.6855128407478333)
# ('simulations_role-playing', 0.6846071481704712)
# ('project-centered', 0.6826268434524536)
# ('hands-on/minds-on', 0.6808892488479614)
#
# T0P 15 WORDS CLOSEST TO problem-based
# ('problem-based_learning', 0.7890996932983398)
# ('integrated_interdisciplinary', 0.7848905324935913)
# ('content-specific_grade-by-grade', 0.7842892408370972)
# ('laboratory-based', 0.7822384834289551)
# ('hands-on_minds-on', 0.7795132398605347)
# ('discussion-based', 0.7788670063018799)
# ('design-based', 0.7777847051620483)
# ('hands-on_and_minds-on', 0.777582049369812)
# ('project-centered', 0.7771323919296265)
# ('technology-infused', 0.7769192457199097)
# ('life-based', 0.7765124440193176)
# ('hands-on/minds-on', 0.7760508060455322)
# ('socratic', 0.7760000228881836)
# ('simulations_role-playing', 0.7742791175842285)
# ('inquiry_arcs', 0.7734700441360474)
#
# T0P 15 WORDS CLOSEST TO discovery-based
# ('learn-by-doing', 0.8363640308380127)
# ('seminar-based', 0.8189511895179749)
# ('language-rich', 0.8160936236381531)
# ('unschooling_is_a_less', 0.8155924081802368)
# ('developmentally-based', 0.8151591420173645)
# ('nuturing', 0.8126906156539917)
# ('values-centered', 0.8097946047782898)
# ('developmentallyappropriate', 0.8090020418167114)
# ('sensory-rich', 0.80750572681427)
# ('project-centered', 0.8046090602874756)
# ('explorative', 0.8015897274017334)
# ('cognitively_demanding', 0.8008060455322266)
# ('andinnovative', 0.8005708456039429)
# ('literature-rich', 0.7991681694984436)
# ('low-stress', 0.798554539680481)
#
# T0P 15 WORDS CLOSEST TO experiential
# ('tomorrow_in_rockville', 0.6366349458694458)
# ('integrative', 0.6330317258834839)
# ('journey_for_tma', 0.6237869262695312)
# ('sensory-rich', 0.6203253269195557)
# ('nature-based', 0.6179972887039185)
# ('non-arts_objectives', 0.6178889870643616)
# ('inquiry-driven', 0.612930178642273)
# ('teacher-guided', 0.6102246046066284)
# ('fieldwork_experts', 0.6101946830749512)
# ('hands-on/minds-on', 0.6096264123916626)
# ('service-based', 0.6085801124572754)
# ('literacy-based', 0.6079000234603882)
# ('problem-based_learning', 0.6077450513839722)
# ('project-centered', 0.6064910292625427)
# ('curriculum_that_enhances', 0.6063675284385681)
#
# T0P 15 WORDS CLOSEST TO constructivist
# ('constructivism', 0.7486873865127563)
# ('technology-infused', 0.7210007309913635)
# ('whole-brain', 0.7190081477165222)
# ('child-led', 0.71506667137146)
# ('technology-enriched', 0.7139584422111511)
# ('didactic_materials', 0.7123608589172363)
# ('discussion-based', 0.7111490368843079)
# ('instructional_best-practices', 0.7071788907051086)
# ('integrated_interdisciplinary', 0.707124650478363)
# ('language-rich', 0.7067819833755493)
# ('constructivist_approach', 0.7062184810638428)
# ('brain-based', 0.7042311429977417)
# ('hands-on_minds-on', 0.7038856744766235)
# ('student-centered_inquiry-based', 0.7034156322479248)
# ('developmentally-based', 0.7027567625045776)

# %%
# Can also look for most similar terms across seed dictionary as a whole, and use it to make new dictionary:
inq50new = []
for line in list(model.most_similar(inqseed, topn=50)):
    #print(line[0]) # only print words
    inq50new.append(line[0])
inq50new
# Out:
# ['integrated_interdisciplinary',
#  'technology-infused',
#  'hands-on_and_minds-on',
#  'hands-on/minds-on',
#  'project-centered',
#  'discussion-based',
#  'problem-based_learning',
#  'experiential_approach',
#  'hands-on_minds-on',
#  'life-based',
#  'science-driven',
#  'language-rich',
#  'simulations_role-playing',
#  'cognitively_demanding',
#  'literacy-based',
#  'developmentally-based',
#  'sensory-rich',
#  'inquiry-driven',
#  'student-driven_exploration',
#  'hand-on',
#  'whole-brain',
#  'hands‑on',
#  'active_inquiry',
#  'concrete_manipulative',
#  'content-specific_grade-by-grade',
#  'design-based',
#  'interdisciplinary_project-based',
#  'andinnovative',
#  'explorative',
#  'out-the-door',
#  'student-centered_inquiry-based',
#  'exploration_and_experimentation',
#  'thematic_integrated',
#  'experiential_project-based',
#  'seminar-based',
#  'socratic',
#  'experientially',
#  'literature-rich',
#  'interdisciplinary_and_multi-dimensional',
#  'interdisciplinary_explorations',
#  'inter-disciplinary',
#  'rigorous_skills-based',
#  'cross-disciplinary',
#  'socratic_dialogue',
#  'life-enhancing_skills',
#  'discovery-based_learning',
#  'movement-based',
#  'technology-enriched',
#  'siop_sheltered',
#  'child-centered_individualized']

# %%
# By searching through the above candidate terms/phrases, expand from the seed terms into a conceptually tight list like this: 
inq30 = ['discovery-based', 'student-driven_exploration', 'exploration_and_experimentation', 'laboratory-based', 
         'problem-based', 'prbl', 'learn-by-doing', 
         'project-based', 'project-centered', 
         'experiential', 'experiential_approach', 'experientially',
         'inquiry-based', 'inquiry-driven', 'student-centered_inquiry-based', 'active_inquiry', 
         'constructivist', 'constructivism', 
         'hands-on', 'hand-on', 'hands-on_learning', 'hands-on_and_minds-on', 'hands-on_minds-on', 'hands-on/minds-on', 
         'socratic', 'socratic_method', 'socratic_dialogue',
         'child-centered', 'learner-centered', 'student-centered']

inq50 = ['inquiry-based', 'problem-based', 'discovery-based', 'experiential', 'constructivist', 'hands-on', 
         'experiential_learning', 'creative', 'problem-solving', 'critical_thinking', 'real_world', 'creativity', 
         'project-based', 'exploration', 'curiosity', 'investigate', 'real-life', 'student-centered', 'critical_thinkers', 
         'expeditions', 'child-centered', 'experimentation', 'explorations', 'student-based', 'immersive', 'activity-based', 
         'open-mindedness', 'student-driven', 'intrinsically', 'reality-based', 'learner-centered', 'interest-based', 
         'minds-on', 'metacognitive', 'experience-based', 'constructivism', 'project-based', 'student-directed', 
         'project-oriented', 'inquiry/research', 'project-focused', 'stimulate_critical', 'student-centric', 'active_inquiry', 
         'inquiry-driven', 'child-directed', 'child-initiated', 'experientially', 'problem-centered', 'project-centered']

# Could add more terms, too:
model.most_similar(inq30, topn=500)
# Out:
# [('life-based', 0.9011286497116089),
#  ('discussion-based', 0.8966033458709717),
#  ('andinnovative', 0.8952078819274902),
#  ('language-rich', 0.89271479845047),
#  ('science-driven', 0.8912979960441589),
#  ('integrated_interdisciplinary', 0.8899644613265991),
#  ('technology-infused', 0.8862203359603882),
#  ('whole-brain', 0.8859595060348511),
#  ('cognitively_demanding', 0.884796142578125),
#  ('sensory-rich', 0.8831244707107544),
#  ('rigorous_skills-based', 0.8811208009719849),
#  ('seminar-based', 0.8805467486381531),
#  ('design-based', 0.8767224550247192),
#  ('goal-driven', 0.8765220642089844),
#  ('multi-modality', 0.8756349682807922),
#  ('simulations_role-playing', 0.874825119972229),
#  ('life-enhancing_skills', 0.8745526075363159),
#  ('concrete_manipulative', 0.8743171095848083),
#  ('content-specific_grade-by-grade', 0.8741116523742676),
#  ('movement-based', 0.8723524808883667),
#  ('iqwst', 0.8722272515296936),
#  ('outside-the-box', 0.8719028830528259),
#  ('literature-rich', 0.8696819543838501),
#  ('experiential_project-based', 0.8696408867835999),
#  ('inventive_thinking', 0.869335412979126),
#  ('discovery-based_learning', 0.8690539002418518),
#  ('developmentally-based', 0.8680057525634766),
#  ('cross-curricular_approach', 0.8672816753387451),
#  ('hands‑on', 0.8672585487365723),
#  ('common-core_aligned', 0.8661572337150574),
#  ('skills.the', 0.8660205006599426),
#  ('inquiry_arcs', 0.8658308982849121),
#  ('fieldwork_and_experts', 0.8657243847846985),
#  ('problem-based_learning', 0.8645853400230408),
#  ('proven_methodology', 0.8644869327545166),
#  ('recursive', 0.8641742467880249),
#  ('child-centered_individualized', 0.8632643818855286),
#  ('interdisciplinary_and_multi-dimensional', 0.8632445931434631),
#  ('minds-on', 0.863106906414032),
#  ('technology-enriched', 0.8625757694244385),
#  ('explorative', 0.8625093102455139),
#  ("'real-world", 0.8618983030319214),
#  ('concept-driven', 0.8618360161781311),
#  ('technology-rich_environment', 0.861474871635437),
#  ('out-the-door', 0.861263632774353),
#  ('interdisciplinary_explorations', 0.8609186410903931),
#  ('literacyinstruction', 0.8607892394065857),
#  ('incorporating_the_principles', 0.8605504035949707),
#  ('observation_and_experimentation', 0.8591469526290894),
#  ('literacy-based', 0.8589853644371033),
#  ('problem-centered', 0.8583693504333496),
#  ('interdisciplinary_units', 0.8575376272201538),
#  ('learningand', 0.8571810722351074),
#  ('discovery_exploration', 0.8569053411483765),
#  ('constructivist-based', 0.8566786050796509),
#  ('child-led', 0.8562513589859009),
#  ('kāʻeo', 0.8561899662017822),
#  ('activity-oriented', 0.8556005954742432),
#  ('research-backed', 0.8549044728279114),
#  ('standards-driven', 0.8545426726341248),
#  ('low-stress', 0.8543645143508911),
#  ('nuturing', 0.8538314700126648),
#  ('inwhich', 0.8536551594734192),
#  ('constructivist_pedagogy', 0.8536282777786255),
#  ('object-oriented', 0.8534907102584839),
#  ('hands-on-learning', 0.8534513711929321),
#  ('issues-based', 0.8533228039741516),
#  ('kagan_cooperative', 0.8531111478805542),
#  ('team-focused', 0.8530192375183105),
#  ('provides_a_myriad', 0.8529514074325562),
#  ('values-centered', 0.8527814149856567),
#  ('cross-curricular_project-based', 0.8527790904045105),
#  ('activity-based', 0.8527095317840576),
#  ('foss_modules', 0.8526763916015625),
#  ('sustained_inquiry', 0.8526188135147095),
#  ('in-depth_interdisciplinary', 0.852394163608551),
#  ('flexible_groupings', 0.8523692488670349),
#  ('constructivists', 0.8521972894668579),
#  ('systematic_and_explicit', 0.8515188097953796),
#  ('placed-based', 0.8511872291564941),
#  ('teacher-student_interactions', 0.8511817455291748),
#  ('multi-modal_approach', 0.8502551317214966),
#  ('includes_mini-lessons', 0.850070595741272),
#  ('engagestudents', 0.8498767018318176),
#  ('interdisciplinary_project-based', 0.8496181964874268),
#  ('engineering_is…', 0.849113941192627),
#  ('thematically_integrated', 0.8488203883171082),
#  ('nature_journaling', 0.848663866519928),
#  ('internships_and_apprenticeships', 0.8485034704208374),
#  ('value-based', 0.8483516573905945),
#  ('sel-inspired', 0.8482190370559692),
#  ('approaches_such_as_sheltered', 0.8479781150817871),
#  ('language-rich_environment', 0.847888708114624),
#  ('academically-integrated', 0.8477975726127625),
#  ('dovetail', 0.8477013111114502),
#  ('extended_student-influenced', 0.8476594090461731),
#  ('experience-based', 0.8474299311637878),
#  ('realworld_hands-on', 0.8474035263061523),
#  ('common_core-based', 0.8471046686172485),
#  ('multi-modal', 0.8470701575279236),
#  ('project-oriented', 0.8470489382743835),
#  ('real-world_problem-solving', 0.8469380140304565),
#  ('unschooling_is_a_less', 0.8468334674835205),
#  ('singapore_math®', 0.8466399908065796),
#  ('siop_sheltered', 0.846480131149292),
#  ('discipline-based', 0.8460747003555298),
#  ('standards-based_data-driven', 0.845748245716095),
#  ('ignite_curiosity', 0.845730721950531),
#  ('seminar-style', 0.8454281091690063),
#  ('project‐based', 0.8452104330062866),
#  ('highly_motivating', 0.8451411724090576),
#  ('culturally-based', 0.8451286554336548),
#  ('child-directed', 0.8450213670730591),
#  ('data-driven_differentiated', 0.8449467420578003),
#  ('customization_options', 0.8448182940483093),
#  ('arts-integrated_approach', 0.8445711135864258),
#  ('creativity_and_problem-solving', 0.8445570468902588),
#  ('imyc', 0.8445377349853516),
#  ('places_a_premium', 0.8442980647087097),
#  ('toinvestigate', 0.84413743019104),
#  ('creatinga', 0.8441073894500732),
#  ('fostering_curiosity', 0.8440285921096802),
#  ('incorporating_real-world', 0.8438678979873657),
#  ('constructive_processes', 0.8437701463699341),
#  ('observation_questioning', 0.843643844127655),
#  ('engaging_and_stimulating', 0.8435956239700317),
#  ('fused', 0.843134343624115),
#  ('activities/lessons', 0.8431060314178467),
#  ('promising_pages', 0.843015193939209),
#  ('creativity_and_self-expression', 0.8429305553436279),
#  ('meaningful_real-life', 0.8423786163330078),
#  ('culturally-rich', 0.8422722816467285),
#  ('reflective_thinking', 0.8422250747680664),
#  ('andinterests', 0.8421221971511841),
#  ('kinaesthetic', 0.8418565392494202),
#  ('outcome-focused', 0.8417764902114868),
#  ('thematic_integrated', 0.8413978815078735),
#  ('multi-aged_learning', 0.8413947820663452),
#  ('colloquia', 0.8413095474243164),
#  ('backwards_design', 0.8412115573883057),
#  ('computer-mediated', 0.8411075472831726),
#  ('rotating_stations', 0.8411006927490234),
#  ('awaken_the_imagination', 0.8410714864730835),
#  ('meaningful_and_memorable', 0.8409566283226013),
#  ('instructional_best-practices', 0.8408517837524414),
#  ('inquiry/research', 0.8405863046646118),
#  ('human-centered', 0.8404054641723633),
#  ('synthetic_phonics', 0.8402007818222046),
#  ('arts-integration', 0.8401075005531311),
#  ('personlized', 0.8399252891540527),
#  ('visually_oriented', 0.8398653268814087),
#  ('writing-centered', 0.8398633599281311),
#  ('developmentallyappropriate', 0.8398444652557373),
#  ('practice-based', 0.8396217226982117),
#  ('hands‐on', 0.839604377746582),
#  ('high-engagement', 0.8395857810974121),
#  ('afrikan', 0.8393802642822266),
#  ('tprs', 0.8390734195709229),
#  ('expeditions.', 0.8389319181442261),
#  ('knowledge-rich', 0.8388117551803589),
#  ('critique_and_reflection', 0.838719367980957),
#  ('inter-grade', 0.8382226228713989),
#  ('brain-compatible', 0.8381826281547546),
#  ('encouraging_an_unstructured', 0.8380569219589233),
#  ('assume_ownership', 0.8380521535873413),
#  ('multi-layered', 0.8380351066589355),
#  ('content-driven', 0.8375552296638489),
#  ('curriculum.our', 0.8375034928321838),
#  ('child-initiated', 0.8374812602996826),
#  ('individualistic', 0.8372912406921387),
#  ('thoughtfully_designed', 0.837265133857727),
#  ('structured_and_predictable', 0.8371744155883789),
#  ('integrated/interdisciplinary', 0.837148129940033),
#  ('fosters_life-long', 0.8370988965034485),
#  ('moves_from_the_concrete', 0.8370491862297058),
#  ('thescientific', 0.8370063304901123),
#  ('self-correction', 0.8368204832077026),
#  ('hands-on_multisensory', 0.8367267847061157),
#  ('creativity_and_originality', 0.8365703821182251),
#  ('authentic_and_meaningful', 0.8365300297737122),
#  ('classes/assignments', 0.8364394307136536),
#  ('feedback-rich', 0.8363842964172363),
#  ('collegial_sharing', 0.83628249168396),
#  ('experiential_constructivist', 0.8360756635665894),
#  ('non-arts_objectives', 0.835864782333374),
#  ('intercultural_awareness', 0.8357274532318115),
#  ('pedagogical_approach', 0.8356013894081116),
#  ('way™', 0.8354429006576538),
#  ('studies-based', 0.835210919380188),
#  ('micro-economic_ventures', 0.8351525068283081),
#  ('child-initiated_play', 0.835051417350769),
#  ('cross-disciplinary', 0.8346491456031799),
#  ('authentic_real-world', 0.8345082402229309),
#  ('ipc_and_imyc', 0.8344739079475403),
#  ('instruction_cgi', 0.8344581127166748),
#  ('ecopedagogical_praxis', 0.8342888951301575),
#  ('creative_and_imaginative', 0.8341919779777527),
#  ('systematic_and_sequential', 0.8339704275131226),
#  ('investigative_inquiry-based', 0.8337103128433228),
#  ('interactive_multimedia', 0.8336182832717896),
#  ('classical/stem_based', 0.8335806131362915),
#  ('firmer', 0.8333056569099426),
#  ('environmental_consciousness', 0.8331362009048462),
#  ('inquiry-based_approach', 0.8330440521240234),
#  ('unique_and_engaging', 0.83301842212677),
#  ('inquiry-based_units', 0.8328099250793457),
#  ('two-teacher_model', 0.8327741622924805),
#  ('marzano_strategies', 0.8327649831771851),
#  ('inter-disciplinary', 0.8325643539428711),
#  ('projects-based', 0.8325004577636719),
#  ('second-language_acquisition', 0.8324637413024902),
#  ('leading-edge', 0.8322160840034485),
#  ('physically_and_intellectually', 0.8319194316864014),
#  ('inherently_rigorous', 0.8318719267845154),
#  ('technology-rich', 0.8318081498146057),
#  ('inacademic', 0.8317626118659973),
#  ('nature-oriented', 0.8316193222999573),
#  ('beyond_memorization', 0.8315515518188477),
#  ('long-term_in-depth', 0.8314504623413086),
#  ('haumāna', 0.8310064077377319),
#  ('discussion-based_assessment', 0.8309929966926575),
#  ('teaching-learning', 0.8308967351913452),
#  ('culturally-appropriate', 0.8308572173118591),
#  ('blearning', 0.8307900428771973),
#  ('direct-instruction', 0.8306925296783447),
#  ('rather_than_rote', 0.8306850790977478),
#  ('learning-based', 0.8305860757827759),
#  ('small-school_atmosphere', 0.830478847026825),
#  ('competence_and_confidence', 0.8304552435874939),
#  ('research-based_teacher-tested', 0.8303499817848206),
#  ('essential_21st-century', 0.8302068710327148),
#  ('challenging_and_stimulating', 0.8301634192466736),
#  ('facilitates_skills-based', 0.8300443887710571),
#  ('blended-learning_model', 0.8299806118011475),
#  ('specially-designed', 0.8299728631973267),
#  ('life\xadlong', 0.8299599885940552),
#  ('synapse', 0.829767107963562),
#  ('continual_reflection', 0.8297100067138672),
#  ('fun_with_phonograms', 0.8296970129013062),
#  ('intertwining', 0.8296515941619873),
#  ('designing_and_facilitating', 0.8296425342559814),
#  ('responsive_pedagogy', 0.8295506238937378),
#  ('subject-area_integration', 0.8293007612228394),
#  ('stem-oriented', 0.8292982578277588),
#  ('strengths_and_passions', 0.8292298316955566),
#  ('inquiry-based_investigative', 0.8292115926742554),
#  ('pop-up_micro-schools', 0.8291912078857422),
#  ('incorporate_movement', 0.8291620016098022),
#  ('mutt-i-grees', 0.8290767073631287),
#  ('infusion_of_flocabulary', 0.8290703296661377),
#  ('proven_methods', 0.8290534019470215),
#  ('highly_motivational', 0.8290148973464966),
#  ('approaches_and_strategies', 0.8289839029312134),
#  ('tomlinson_mctighe', 0.8289007544517517),
#  ('scientifically-based_reading', 0.8288995027542114),
#  ('teacher-developed', 0.8288899660110474),
#  ('inquiry_arc', 0.828871488571167),
#  ('nurtures_creativity', 0.828795313835144),
#  ('learning…', 0.8287246227264404),
#  ('learningexperiences', 0.8285825252532959),
#  ('systematic_and_cumulative', 0.8285216689109802),
#  ('questioning_strategies', 0.8284204006195068),
#  ('ensemble-based', 0.8283975124359131),
#  ('andservice', 0.8283463716506958),
#  ('exploring_and_experimenting', 0.8282973766326904),
#  ('social-emotional_intelligence', 0.8282884359359741),
#  ('faculty-led', 0.8281819820404053),
#  ('adaptive_curriculum', 0.8281815052032471),
#  ('encompass_engaging', 0.828112006187439),
#  ('out-of-classroom_experiences', 0.8281064033508301),
#  ('rotate_through_stations', 0.8277953863143921),
#  ('coherent_sequenced', 0.8277725577354431),
#  ('media-rich', 0.8277644515037537),
#  ('deepen_the_understanding', 0.8276754021644592),
#  ('cohesiveness', 0.827601432800293),
#  ('logical_thought', 0.8275789022445679),
#  ('child-sized_furniture', 0.8275684118270874),
#  ('service-based', 0.8274885416030884),
#  ('technologies_and_our_science-based', 0.8274471163749695),
#  ('computer-based_software', 0.8274281024932861),
#  ('uses_data-based', 0.8273564577102661),
#  ('outside-the-box_thinking', 0.827329695224762),
#  ('aboard_the_biobus', 0.8272478580474854),
#  ('student-powered', 0.8270033001899719),
#  ('multi-disciplinary_integrated', 0.8269802331924438),
#  ('brain-friendly', 0.826896071434021),
#  ('transdisciplinary_themes', 0.8268671035766602),
#  ('solution-based', 0.8267940878868103),
#  ('motivating_and_engaging', 0.8267666101455688),
#  ('choreograph_dances', 0.8266641497612),
#  ('nurtures_mutual', 0.826583743095398),
#  ('mastery-learning', 0.826520562171936),
#  ('academically_oriented', 0.8265026211738586),
#  ('interest-driven', 0.8264679908752441),
#  ('rather_than_lecturing', 0.8261932134628296),
#  ('environmentally-based', 0.8261863589286804),
#  ('complex_adult-world', 0.8261247277259827),
#  ('outlet_for_expression', 0.8260611891746521),
#  ('relevant_and_challenging', 0.8259620070457458),
#  ('individually_paced', 0.8259119391441345),
#  ('bridges_in_mathematics™', 0.8258315324783325),
#  ('inter-curricular', 0.825785756111145),
#  ('pairs_pre-professional', 0.825684666633606),
#  ('culturally-relevant', 0.8256217241287231),
#  ('child-centric', 0.8256140351295471),
#  ('human-animal', 0.8255214095115662),
#  ('re-engages', 0.8254864811897278),
#  ('joyful_and_engaging', 0.8253083229064941),
#  ('curriculum-centered', 0.8252962231636047),
#  ('heuristic', 0.8251907229423523),
#  ('learning–', 0.825174868106842),
#  ('theoretical_foundations', 0.8250951766967773),
#  ('educator-scripted', 0.8250927925109863),
#  ('nonlinguistic', 0.825063169002533),
#  ('literature-based', 0.8250389099121094),
#  ('open-ended_inquiry', 0.8250107765197754),
#  ('sequence_of_manipulative', 0.8249433040618896),
#  ('mixed-age_grouping', 0.8249257802963257),
#  ('thematic_approach', 0.8248984813690186),
#  ('accordance_with_the_m-dcps', 0.824832558631897),
#  ('cross-curricular_units', 0.824793815612793),
#  ('engagein', 0.8247664570808411),
#  ('appb_teaching', 0.8246405720710754),
#  ('reality-based', 0.8245422840118408),
#  ('reinforce_and_complement', 0.8245294094085693),
#  ('student-centered_project-based', 0.8244593143463135),
#  ('expeditions—', 0.8242402076721191),
#  ('pedagogical_principles', 0.8241477012634277),
#  ('constructing_and_communicating', 0.8240067958831787),
#  ('visual-spatial', 0.8240021467208862),
#  ('integrated_child-centered', 0.8239649534225464),
#  ('well-managed', 0.8238918781280518),
#  ('culturally-responsive', 0.8238497972488403),
#  ('social/_emotional', 0.8237814903259277),
#  ('environmentthat', 0.8236751556396484),
#  ('simulates', 0.8236721754074097),
#  ('pbl/stem', 0.823606014251709),
#  ('artful_thinking', 0.8235869407653809),
#  ('passageworks', 0.8235844373703003),
#  ('theoretical_framework', 0.8235318064689636),
#  ('keyed', 0.8235201835632324),
#  ('acpa_believes', 0.8235180974006653),
#  ('multiple_modalities', 0.8234914541244507),
#  ('implement_data-driven', 0.8232365846633911),
#  ('bigideas', 0.8231852054595947),
#  ('student-driven_projects', 0.8231827616691589),
#  ('steam-based', 0.8231616020202637),
#  ('emergent_literacy', 0.8231609463691711),
#  ('threaded_throughout', 0.8231250643730164),
#  ('rigorously_researched', 0.8230811357498169),
#  ('inquiry-rich', 0.8230751156806946),
#  ('highly-structured', 0.8229793310165405),
#  ('standard-aligned', 0.8229105472564697),
#  ('ofmusic', 0.82286536693573),
#  ('social-emotionally', 0.8228501677513123),
#  ('compaction', 0.8225581645965576),
#  ('scientific_methodology', 0.8224805593490601),
#  ('knowledge_is_interrelated', 0.8223585486412048),
#  ('inculcates', 0.8223103284835815),
#  ('integrated_technology-based', 0.8222750425338745),
#  ('numerical_literacy', 0.8222739696502686),
#  ('hwt', 0.8222088813781738),
#  ('iterating', 0.822091817855835),
#  ('builds_self-confidence', 0.8220880031585693),
#  ('competency-based_progression', 0.8220078945159912),
#  ('best-of-class_texts', 0.8219624161720276),
#  ('leadership-driven', 0.8219391703605652),
#  ('accentuated', 0.8219376802444458),
#  ('learningenvironments', 0.8219221234321594),
#  ('enviornment', 0.8218978643417358),
#  ('strengthen_their_vocabularies', 0.8218669295310974),
#  ('multi-aged_grouping', 0.8218573331832886),
#  ('content-area_knowledge', 0.8218123316764832),
#  ('instills_a_love', 0.8218082785606384),
#  ('increase_in_sophistication', 0.8217506408691406),
#  ('employing_a_variety', 0.8217163681983948),
#  ('intrinsically', 0.821632981300354),
#  ('planetbravo', 0.8215641975402832),
#  ('promote_multi-sensory', 0.8214736580848694),
#  ('decolonizing', 0.8214634656906128),
#  ('cultivate_life-long', 0.8214090466499329),
#  ('mentorships_and_workplace', 0.821274995803833),
#  ('well-designed', 0.8212398290634155),
#  ('core-knowledge', 0.8212298154830933),
#  ('standards-based_differentiated', 0.8211671710014343),
#  ('literature_scientifically', 0.8211230039596558),
#  ('observation_brainstorming', 0.8210831880569458),
#  ('foundational_stages', 0.82096266746521),
#  ('imaginative_thinking', 0.8209545612335205),
#  ('muscular_coordination', 0.8207076787948608),
#  ('project-based-learning', 0.8205671310424805),
#  ('learning-to-learn', 0.8205339908599854),
#  ('spiraled', 0.8203513622283936),
#  ('self-expressive', 0.8202807307243347),
#  ('routines_and_rituals', 0.8202769756317139),
#  ('gef', 0.8202700018882751),
#  ('enhanced_curriculum', 0.8202592134475708),
#  ('humanities_and_the_sciences', 0.8201335668563843),
#  ('materials_are_self-correcting', 0.8200938701629639),
#  ('ideally_suited', 0.8200514912605286),
#  ('career-applicable', 0.8199608325958252),
#  ('challenge-based_learning', 0.8199392557144165),
#  ('strengths-based', 0.8198637962341309),
#  ('interdisciplinary_thematic', 0.8198420405387878),
#  ('teacher-supported', 0.8198367357254028),
#  ('fective', 0.819800853729248),
#  ('self-esteem_and_self-confidence', 0.8197702169418335),
#  ('choice-based_art', 0.8197616338729858),
#  ('codes_of_cooperation', 0.8196781873703003),
#  ('anti-biased_anti-racist', 0.8196308016777039),
#  ('aligned_to_the_ngss', 0.819590151309967),
#  ('renewed_excitement', 0.8195339441299438),
#  ('grit_and_zest', 0.8195145130157471),
#  ('cultivates_both_the_cognitive', 0.8194495439529419),
#  ('using_the_grr', 0.8194413185119629),
#  ('teacher-guided', 0.8193778991699219),
#  ('scientific_exploration', 0.819342851638794),
#  ('reflective_and_thoughtful', 0.8193359375),
#  ('integrated_thematic', 0.8193261623382568),
#  ('proven_methodologies', 0.819287896156311),
#  ('artistic_andexperiential', 0.8190366625785828),
#  ('principle-based', 0.8189231157302856),
#  ('adult-world', 0.8188910484313965),
#  ('self-initiated', 0.8187971115112305),
#  ('world-view', 0.8187732696533203),
#  ('thestudy', 0.8187430500984192),
#  ('*providing', 0.8186501860618591),
#  ('three_and_four-year-olds', 0.8186402320861816),
#  ('multimodal', 0.8186061382293701),
#  ('internal_self-discipline', 0.8185182809829712),
#  ('didactic_materials', 0.8184015154838562),
#  ('tactile_learners', 0.8183812499046326),
#  ('life-skill', 0.8183766603469849),
#  ('paideia_seminar', 0.818314790725708),
#  ('chard_s.c.', 0.8182910680770874),
#  ('instructional_stances', 0.818279504776001),
#  ('self-designed', 0.8182193636894226),
#  ('concrete–pictorial–abstract_learning', 0.8182055354118347),
#  ('non-traditional_environment.', 0.8181531429290771),
#  ('novel-based', 0.8181430101394653),
#  ('small-group_settings', 0.8180926442146301),
#  ('quarter-long', 0.8180502653121948),
#  ('learner-centered_culture', 0.8180345892906189),
#  ('multi-sensory_experiences', 0.8179426193237305),
#  ('school-to-work_transition', 0.8179121017456055),
#  ('meaningful_purposeful', 0.8178764581680298),
#  ('curiosity_and_imagination', 0.8177732229232788),
#  ('re-teaches', 0.8176549673080444),
#  ('real-world_settings', 0.8175620436668396),
#  ('scott-foresman_investigations', 0.8175373077392578),
#  ('-mystery_science', 0.817453145980835),
#  ('handwriting_that_taps', 0.8174507021903992),
#  ('interwoven_throughout', 0.8174071311950684),
#  ('child-driven', 0.817316472530365),
#  ('problem_based/project', 0.8172610998153687),
#  ('knowledge-centered', 0.8172123432159424),
#  ('culturally-supportive_community', 0.8171728253364563),
#  ('computer-enhanced', 0.8171676397323608),
#  ('tools_priceless', 0.8171612620353699),
#  ('standards-focused', 0.817128598690033),
#  ('means_of_differentiating', 0.817089319229126),
#  ('instills_a_sense', 0.8170461654663086),
#  ('heightens', 0.8169928193092346),
#  ('wicor', 0.8168216943740845),
#  ('pedagogical_delivery', 0.8167115449905396),
#  ('efficacious', 0.816666841506958),
#  ('stimulate_critical', 0.8166552782058716),
#  ('push-in_model', 0.8165043592453003),
#  ('conceptual_framework', 0.8163708448410034),
#  ('foss®', 0.8161999583244324),
#  ('practice…', 0.8161801695823669),
#  ('problem‑solving', 0.8161510229110718),
#  ('study/teaching', 0.8161005973815918),
#  ('enduring_relationships', 0.8160312175750732),
#  ('real‐world', 0.8160250782966614),
#  ('rigorous_arts-integrated', 0.8159219026565552),
#  ('depth_breadth', 0.815771758556366),
#  ('project-basedlearning', 0.8157092332839966),
#  ('efficacy_by_encouraging', 0.8156901597976685),
#  ('trans-disciplinary', 0.815593957901001),
#  ('constructivist_approach', 0.8155789971351624),
#  ('interest-based', 0.8155431747436523),
#  ('product/outcome', 0.8153843879699707),
#  ('think-pair-share', 0.8153611421585083),
#  ('wedo', 0.8153342604637146),
#  ('cross-age_buddy', 0.8152990341186523),
#  ('marcy_cook', 0.8152923583984375),
#  ('awell-rounded', 0.8152543306350708),
#  ('dbae', 0.8151702284812927),
#  ('student-driven_project-based', 0.8150975704193115),
#  ('subskills', 0.8150861263275146),
#  ('interactive_media-rich', 0.8150523900985718),
#  ('directly_correlates', 0.814996600151062),
#  ('real-world_relevance', 0.8149932622909546),
#  ('effectiveness_of_metacognitive', 0.8149868249893188),
#  ('multiple_modality', 0.8148128986358643),
#  ('lrpa_implements', 0.8148050904273987),
#  ('p21_framework', 0.8148018717765808),
#  ('vygotsky_s_theory', 0.8146910667419434),
#  ('virtuous_living', 0.8146470785140991)]

# %%
# Can also search for terms that don't match:
model.doesnt_match(inq30)
# Out:
# /opt/conda/lib/python3.7/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'hands-on_learning'

# %%
# Searching for additional terms similar to this list, you can expand even further!
inquiry_fin = [elem.strip('\n') for elem in load_list('data/inquiry.txt')] # Load completed dict of 500 terms
inquiry_fin = list(set(inquiry_fin)) # Remove duplicates

sorted(inquiry_fin) # Show long dictionary resulting from exploring (and hand-cleaning)
# Out:
# ['abilities',
#  'abilities_will_be_maximized',
#  'ability-grouped',
#  'acquire_requisite',
#  'active_inquiry',
#  'activities',
#  'activities/lessons',
#  'activity/project',
#  'adept_at_facilitating',
#  'adherents',
#  'adjusted_and_thrived',
#  'admittedly_fallible',
#  'agile',
#  'aligned_to_the_ngss',
#  'allegiances',
#  'altered/added',
#  'amazed_by_the_generosity',
#  'anecdotes',
#  'appealing_and_relevant',
#  'approaches_such_as_sheltered',
#  'appropriately_allocated',
#  'architecture',
#  'arguments_and_informative/explanatory',
#  'arithmetic_reasoning',
#  'art-filled',
#  'artistic',
#  'assemble_the_pieces',
#  'atomic_nucleus',
#  'awaken_the_imagination',
#  'bearing_on_the_viability',
#  'benefits_of_co-op',
#  'bi-literacy',
#  'brain-compatible',
#  'brain-friendly',
#  'break/gross_motor',
#  'brighter_tomorrow',
#  'brilliantly_infused',
#  'brochure_to_solidify',
#  'c++_programming',
#  'capitalism_and_socialism',
#  'career-focused_and_technical',
#  'carefully_weigh',
#  'case-based',
#  'championing_issues',
#  'channels_their_energies',
#  'character-based_strengths',
#  'checking-for-understanding',
#  'child-centered',
#  'child-centered_individualized',
#  'child-sized_furniture',
#  'circles_graphed',
#  'circulatory_and_nervous',
#  'city-planning',
#  'civically_active',
#  'classical/stem_based',
#  'climate_improvement/improvement',
#  'coaches/leaders',
#  'cogent',
#  'cognitively_demanding',
#  'coherent_sequenced',
#  'cohesiveness',
#  'collaborate_on_a_large-scale',
#  'collaborative_student-community',
#  'college-level_options',
#  'colorism',
#  'comma_rules',
#  'commensurate_with_their_abilities',
#  'committing_offenses',
#  'commonly_confused',
#  'communication/collaboration',
#  'community-wide',
#  'comparing_the_inputs',
#  'compelling_paragraphs',
#  'competency_and_mastery',
#  'complex_adult-world',
#  'complexity',
#  'comprehensibility',
#  'comprehensive_16-hour',
#  'conceiving',
#  'concept/skill',
#  'concurrently_with_the_choreography',
#  'considering_waldorf',
#  'constructivism',
#  'constructivist',
#  'constructivist-based',
#  'consultation/collaboration',
#  'content-rich_nonfiction',
#  'content-specific',
#  'context',
#  'continous',
#  'continuity_and_commitment',
#  'core-content_courses',
#  'craftsmanship',
#  'create_spectacles',
#  'creative',
#  'creativity',
#  'critical-thinkers',
#  'critical-thinking',
#  'cross-content',
#  'crystallization',
#  'cultural_diversities',
#  'cultural_heritages',
#  'curiosity',
#  'curriculum/standards',
#  'data-rich',
#  'decision-making',
#  'decisionmaking_skills',
#  'deepen',
#  'deeper',
#  'definiteness',
#  'demanding_college-preparatory',
#  'derivations',
#  'describe_distributions',
#  'design2fab_lab',
#  'develop/implement',
#  'developing',
#  'dialoguing',
#  'diaries_and_journals',
#  'different/',
#  'differentiated/personalized',
#  'differing_structure',
#  'discerning_listeners',
#  'discover',
#  'discovery-based',
#  'disempower',
#  'disparate_personalities',
#  'dissection_techniques',
#  'dissipate',
#  'distraction-free',
#  'drafting_and_revising',
#  'drove_the_expedition',
#  'dynamic_collaboration',
#  'dynamically_and_immediately',
#  'edifying',
#  'editing_and_proofing',
#  'effectiveness_of_metacognitive',
#  'effects_of_repetition',
#  'efficacy_by_encouraging',
#  'eliminating_unnecessary',
#  'elitism',
#  'ellipsis_points',
#  'embraced_and_supported',
#  'emojis',
#  'encourage',
#  'encouraging',
#  'enduring_conceptual',
#  'enduring_relationships',
#  'engaged_citizen',
#  'engaging',
#  'enlargement',
#  'ennoble',
#  'ennobling_effect',
#  'environment',
#  'equipping_educators',
#  'esl/family',
#  'evaluate_the_motives',
#  'evidence_in_a_nuanced',
#  'examples_evoke',
#  'expeditions',
#  'experience-based',
#  'experiental_learning',
#  'experiential',
#  'experiential_approach',
#  'experientially',
#  'experimental_labs',
#  'experimentation',
#  'exploration',
#  'exploration_and_experimentation',
#  'explorations',
#  'explorative',
#  'expose_them_to_a_wider',
#  'exposed_to_a_coherent',
#  'facilitation_techniques',
#  'faint_of_heart',
#  'feedback',
#  'field-based',
#  'fieldwork',
#  'filming',
#  'fiscal_mismanagement',
#  'force_to_be_reckoned',
#  'fostered',
#  'fostering',
#  'fuels_my_desire',
#  'fully-vetted',
#  'functional_weakness',
#  'gender-nonconforming',
#  'generalizations_and_predictions',
#  'gets_maximized',
#  'goal-driven',
#  'gods_of_asgard',
#  'grade-by-grade_year-by-year',
#  'gradual_manner',
#  'grander_scale',
#  'grapple_with_difficult',
#  'greek_philosophers',
#  'grit_and_zest',
#  'growth',
#  'hand-on',
#  'hands-on',
#  'hands-on/minds-on',
#  'hands-on_and_minds-on',
#  'hands-on_learning',
#  'hands-on_minds-on',
#  'hands‑on',
#  'harmonize',
#  'headmaster_letters',
#  'helps',
#  'higher-level_cognitive',
#  'highly_scripted',
#  'home-away-from-home',
#  'homeschool-friendly',
#  'hope',
#  'humanism',
#  'humanities_major',
#  'identification_of_learning/behavioral',
#  'immersive',
#  'implant_into_the_memories',
#  'in-demand_transportable',
#  'incorporating_the_principles',
#  'increased_connectedness',
#  'independence',
#  'indispensable',
#  'individual/personalized_manner',
#  'individualize_and_differentiate',
#  'inflected',
#  'innovativeness',
#  'inquiry-based',
#  'inquiry-driven',
#  'inquiry/research',
#  'inspire',
#  'inspiring',
#  'instruction_cgi',
#  'integrated',
#  'intelligent_and_intentional',
#  'inter-dependence',
#  'interdependence',
#  'interdisciplinary',
#  'interests',
#  'interior_monologue',
#  'internship/interest',
#  'interpersonal',
#  'investigate',
#  'issues-based',
#  'item/category_to_better',
#  'jasmine_flower',
#  'journaling',
#  'joy-filled',
#  'kinaesthetic',
#  'laboratory-based',
#  'laborious_process',
#  'language-rich',
#  'leader_and_a_follower',
#  'learn',
#  'learn-by-doing',
#  'learner-centered',
#  'learning',
#  'learning-to-learn',
#  'lens',
#  'life-based',
#  'life-long',
#  'life-skill',
#  'lifelong',
#  'lightness',
#  'literature-rich',
#  'literature_has_tended',
#  'loving_and_attentive',
#  'low-ability',
#  'lowest_in_achievement',
#  'loyalty',
#  'math/engineering',
#  'maturationally_ready',
#  'meaningful',
#  'mentorship',
#  'mentorships',
#  'metacognitive',
#  'micro-economic_ventures',
#  'minds',
#  'minds-on',
#  'mirror_real-life',
#  'mixed-ability',
#  'modality',
#  'motivate_their_attempts',
#  'mud_hut',
#  'multi-dimensional',
#  'multi-disciplinary',
#  'multi-faceted',
#  'multiple-paragraph',
#  'must-reads',
#  'mutual',
#  'myon_reader',
#  'mythological_creature',
#  'natural',
#  'nature',
#  'nature-based_perspective',
#  'navigable',
#  'near-daily_basis',
#  'need-to-know_facts',
#  'needing_improvement',
#  'neuro-anatomy',
#  'next_generation',
#  'non-arts',
#  'non-coercive',
#  'non-dominant',
#  'non-instrumental',
#  'non-montessori',
#  'noninfectious',
#  'nonpolitical',
#  'novel-based',
#  'nurtures_mutual',
#  'nurturing',
#  'observation',
#  'obsolescence',
#  'one-segment',
#  'one2one_digital',
#  'open-mindedness',
#  'orientating',
#  'originated_in_cuba',
#  'outcome-focused',
#  'pace_most_suited',
#  'parabolas_graphed',
#  'parent/student/staff_compact',
#  'participating_in_acting/music/arts',
#  'particularly_vulnerable',
#  'pedagogical_delivery',
#  'pep-rally',
#  'personalized',
#  'perspective',
#  'philosophical',
#  'philosophies',
#  'photographing',
#  'pinata',
#  'point-of-need',
#  'polite_manners',
#  'post-production_editing',
#  'post-school_life',
#  'power_of_student-faculty',
#  'powers_of_abstraction',
#  'practicality',
#  'prbl',
#  'pre-teach',
#  'precise_claim',
#  'predicated_on_the_realization',
#  'presumption_and_belief',
#  'problem-based',
#  'problem‑solving',
#  'process-based_writing',
#  'processes_recursively',
#  'product/outcome',
#  'prohibitively_expensive',
#  'project-based',
#  'project-centered',
#  'project-focused',
#  'providing',
#  'proxy_servers',
#  'purveyors',
#  'qualify_or_justify',
#  'quality-learning',
#  'quantitatively_as_well',
#  'quiet',
#  'ramp-up_to_readiness',
#  're-forming',
#  'real-life',
#  'real-world',
#  'reason_mathematically',
#  'rectangular_array',
#  'reduces_distractions',
#  'refine_gross',
#  'reinforce_previously',
#  'reinterpret',
#  'reinvention',
#  'relatable_characters',
#  'relational_capacity',
#  'relationship-oriented_classroom',
#  'relationships_between_pollinators',
#  'relevant_to_the_viability',
#  'reliability',
#  'repeated_occurrence',
#  'research-supported',
#  'respective_histories',
#  'review_of_progress-monitoring',
#  'reﬂective',
#  'richness_and_diversity',
#  'richness_and_strength',
#  'robot_to_maneuver',
#  'rule-making',
#  'scaled_scores',
#  'school-life',
#  'sculptural_forms',
#  'sculptural_techniques',
#  'self-appreciation',
#  'self-awareness',
#  'self-efficacy',
#  'self-expression',
#  'self-motivated',
#  'sense_of_reverence',
#  'sensory-motor',
#  'sensory-rich',
#  'sentence_workshopping',
#  'settled_tribe',
#  'shapes_and_their_attributes',
#  'shared',
#  'sherry_alam',
#  'shows_that_metacognitive',
#  'simulations_role-playing',
#  'skills/family',
#  'small-group',
#  'small-group_discussion',
#  'social/soft',
#  'socialresponsibility',
#  'socratic',
#  'socratic_dialogue',
#  'socratic_method',
#  'standards-focused',
#  'staunch_supporter',
#  'stepstone_360°',
#  'stewards',
#  'stopped_and_looked',
#  "story's_lesson",
#  'stress-management',
#  'strict/warm',
#  'structurally_similar',
#  'structured_and_predictable',
#  'struggles_and_questioning',
#  'stuck_with_them_affecting',
#  'student-centered',
#  'student-centered_inquiry-based',
#  'student-directed',
#  'student-driven',
#  'student-driven_exploration',
#  'study/teaching',
#  'styles_and_modalities',
#  'subject-area_integration',
#  'succesful',
#  'suit_their_needs',
#  'superbowl_party',
#  'supplemental_curricula',
#  'sustainability',
#  'sustaining_of_a_genuine',
#  'symbolic_representations',
#  'synthetic_phonics',
#  'systematic_and_sequential',
#  'tacitly',
#  'target/objective',
#  'teacher-to-teacher',
#  'team-based_organizational',
#  'techniques_namely',
#  'technological_modalities',
#  'technologies_and_our_science-based',
#  'technology-assisted',
#  'technology-infused',
#  'technology–',
#  'tedxyouth',
#  'temper_tantrum',
#  'text-analysis',
#  'text_capitalcitypcs',
#  'textbooks_affording',
#  'thematic',
#  'thematically',
#  'theme-based',
#  'themes',
#  'theses',
#  'thorough_and_accurate',
#  'three-part_pattern',
#  'thrives',
#  'tight-knit',
#  'time-management',
#  'timeless_but_indispensable',
#  'touchpoints',
#  'trained_appraisers',
#  'transgender',
#  'tricycle',
#  'trustee_elections',
#  'tunnels_and_snowshed',
#  'twinery',
#  'unbidden_encounter',
#  'understand',
#  'understands',
#  'unfamiliar_contexts',
#  'unschooling',
#  'uphold_and_enforce',
#  'valued',
#  'values-centered',
#  'virtues',
#  'virtuous',
#  'visible_men',
#  'vitals',
#  'voluntarism',
#  'wampanoag',
#  'warm/strict',
#  'ways_of_knowing/learning',
#  'well-articulated_standards-based',
#  'well-developed',
#  'whole-group_explicit',
#  'willow_seedling',
#  'wishful',
#  'world-view',
#  'would_be_off-putting',
#  'writing-centered',
#  'writing—decoding',
#  'yet-to-be-defined_future']

# %%
# Remove any terms from full dict NOT in current model:
for word in inquiry_fin:
    if word not in list(model.vocab):
        inquiry_fin.remove(word)
        print("Removed " + str(word) + " from core dictionary.")
# Repeat for quality:
for word in inquiry_fin:
    if word not in list(model.vocab):
        inquiry_fin.remove(word)
        print("Removed " + str(word) + " from core dictionary.")
# Out:
# Removed stuck_with_them_affecting from core dictionary.
# Removed styles_and_modalities from core dictionary.

# %% [markdown]
# ### Check terms similar to IBL dictionaries

# %% [markdown]
# ## Visualize vector relationships

# %% [markdown]
# ### Most similar words

# %%
# Display 30 closest words to test word
display_closestwords(model, test_word, 30)

# %% [markdown]
# ### Manually defined words

# %%
# TO DO: Adapt function above to be able to perform this visualization
# Set terms for visualization:
core_words = inqseed
close_words = inq50 

# Define model parameters
dimensions = 300
arr = np.empty((0,dimensions), dtype='f')
word_labels = []

# add the vector for each of the closest words to the array
for wrd_label in close_words:
    wrd_vector = model[wrd_label]
    word_labels.append(wrd_label)
    arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
# find tsne coords for 2 dimensions, using cosine distances as metric
tsne = TSNE(n_components=2, random_state=0, metric=distance.cosine)
np.set_printoptions(suppress=True)
Y = tsne.fit_transform(arr)

x_coords = Y[:, 0]
y_coords = Y[:, 1]

# display scatter plot
fig, ax = plt.subplots(figsize=(20,20))
ax.scatter(x_coords, y_coords, alpha=1, color='b')

sns.set(style='white')

for label, x, y in zip(word_labels, x_coords, y_coords):
    if label in core_words:
        ax.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points', fontweight='bold').set_fontsize(20)
    else:
        ax.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points').set_fontsize(20)
    
ax.set_xlim(x_coords.min()-5, x_coords.max()+50)
ax.set_ylim(y_coords.min()-5, y_coords.max()+5)
ax.set_xlabel('t-SNE dimension 1')
ax.set_ylabel('t-SNE dimension 2')
ax.xaxis.label.set_fontsize(24)
ax.yaxis.label.set_fontsize(24)
for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)
plt.show()

# %%
fig.savefig("data/IBL_50_100919.png", facecolor="white", transparent=True)

# %% [markdown]
# ## Check word frequencies and ranks

# %% [markdown]
# ### Count frequency of candidate words
#
# Required arguments for `count_master()` function:
# - df: DataFrame with text data, each of which is a list of full-text pages (not necessarily preprocessed)
# - dict_path: file path to folder containing dictionaries
# - dict_names: names of dictionaries on file (list or list of lists)
# - file_ext: file extension for dictionary files (probably .txt)
# - local_dicts: list of local dictionaries formatted as last of lists of terms--or if singular, just a list of terms
# - local_names: names of local dictionaries (list or list of lists)

# %%
# For counting word frequencies in corpus (to assess candidate words):
from count_dict import load_dict, Page, dict_precalc, dict_count, create_cols, count_words, collect_counts, count_master

# %%
countsdfs_IBL500 = count_master(df, dict_path = dict_path, dict_names = [], file_ext = '.txt', 
                         local_dicts = [inquiry_fin], local_names = ["candidates"])
# Out:
#   0%|          | 0/367 [00:00<?, ?it/s]
# Counting dictionaries per term for corpus...
# 100%|██████████| 367/367 [03:33<00:00,  1.72it/s]
# 100%|██████████| 367/367 [00:00<00:00, 48950.89it/s]
# Multiprocessing complete. Collecting counts per term per dictionary...
# Finished. Returning results.
# TERM COUNTS FOR CANDIDATES DICTIONARY:
#
#                                       TERM  FREQUENCY
# 19                                learning     336523
# 214                             activities     114357
# 122                                 growth      95806
# 171                           personalized      82667
# 468                                  learn      80238
# ..                                     ...        ...
# 358                          point-of-need          0
# 158              struggles_and_questioning          0
# 156  arguments_and_informative/explanatory          0
# 152             structured_and_predictable          0
# 0                    exposed_to_a_coherent          0
#
# [498 rows x 2 columns]

# %%
countsdfs_IBL500.to_csv("data/inquiry_500_counts.csv")
print(countsdfs_IBL500[0][450:])
countsdfs_IBL500[0][:50]

# %%
# Find the 30 words closest to test word:
inqseed = ['inquiry-based', 'problem-based', 'discovery-based', 'experiential', 'constructivist']

#test_word = "at-risk"
candidate_sims = model.most_similar(inqseed, topn=500)
candidates_list = [pair[0] for pair in candidate_sims] + inqseed # Convert to list for frequency search below
candidate_sims

# %%
countsdfs_IBL5 = count_master(df, dict_path = dict_path, dict_names = [], file_ext = '.txt', 
                         local_dicts = [candidates_list], local_names = ["IBL_candidates"])

# %%
countsdfs_IBL5.to_csv("data/inquiry_seed_similar_counts.csv")
print(countsdfs_IBL5[0][450:])
countsdfs_IBL5[0][:50]

# %%
countsdfs_IBL30 = count_master(df, dict_path = dict_path, dict_names = [], file_ext = '.txt', 
                         local_dicts = [inq30], local_names = ["IBL_candidates"])

# %%
countsdfs_IBL30.to_csv("data/inquiry_30_counts.csv")
print(countsdfs_IBL30[0][450:])
countsdfs_IBL30[0][:50]

# %% [markdown]
# ### Relative ranks of dictionary terms

# %% [markdown]
# Word2vec also has built-in method to compare relative ranks of terms, which go from most frequent (highest number) to least frequent. <br/> **Note** that they are NOT real counts/frequencies (see above for that).

# %%
# Create Counter object: a set containing doubles, where each double is ('term': rank)
counts = Counter({word: vocab.count for (word, vocab) in model.wv.vocab.items()})
counts

# %%
# TO DO: 1. Sort entries by rank before displaying; 2. show histogram of term counts for highest 20 and lowest 20 words for each dict

print("RANK FOR SEED DICTIONARY:")
for term in sorted(inqseed):
    print(str(term) + ": " + str(counts[term]))
print()
print("RANK FOR CORE DICTIONARY:")
for term in inq30:
    print(str(term) + ": " + str(counts[term]))
print()
print("RANK FOR FULL DICTIONARY:")
for term in inquiry_fin:
    print(str(term) + ": " + str(counts[term]))

# %%
# 50 most frequent words (according to word2vec tracker):
model.wv.index2entity[:50]

# %% [markdown]
# ## Validate dictionaries: Check coherence of terms across sizes

# %%
for dictionary in [inqseed, inq30, inq50new, inquiry_fin]:
    print(str(dict_cohere(dictionary, model)))
# Out:
# 0.7010571432113648
# 0.694298374917772
# 0.7891655696868897
# 0.5983296136229586

# %%
# Can also check for words that belong LEAST to a given dictionary:
maindict = inq30

i = 0 # initialize iterator
length = len(maindict) # set length for the for loop
inqtemp = []; inqtemp = maindict # initialize temp list of dict words
similar_words = [] # initialize list of dict words sorted by similarity (least similar words most recently added -> at bottom)

while i < length:
    least_similar_word = model.doesnt_match(inqtemp)
    similar_words.append(least_similar_word)
    inqtemp.remove(least_similar_word)
    i += 1 # add to iterator

print("List of words from least to most similar:")
for term in similar_words:
    print(term)
    
# Need to re-define dictionary again at this point:
inq30 = ['discovery-based', 'student-driven_exploration', 'exploration_and_experimentation', 'laboratory-based', 
         'problem-based', 'prbl', 'learn-by-doing', 
         'project-based', 'project-centered', 
         'experiential', 'experiential_approach', 'experientially',
         'inquiry-based', 'inquiry-driven', 'student-centered_inquiry-based', 'active_inquiry', 
         'constructivist', 'constructivism', 
         'hands-on', 'hand-on', 'hands-on_learning', 'hands-on_and_minds-on', 'hands-on_minds-on', 'hands-on/minds-on', 
         'socratic', 'socratic_method', 'socratic_dialogue',
         'child-centered', 'learner-centered', 'student-centered']
# Out:
# List of words from least to most similar:
# hands-on_learning
# experiential
# hands-on
# student-centered
# child-centered
# project-based
# inquiry-based
# socratic_method
# constructivist
# constructivism
# learner-centered
# socratic
# prbl
# problem-based
# active_inquiry
# hand-on
# hands-on_minds-on
# inquiry-driven
# discovery-based
# experiential_approach
# laboratory-based
# socratic_dialogue
# experientially
# hands-on_and_minds-on
# hands-on/minds-on
# learn-by-doing
# exploration_and_experimentation
# student-driven_exploration
# project-centered
# student-centered_inquiry-based
# /opt/conda/lib/python3.7/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %% [markdown]
# ### Check integrity of IBL dictionaries of varying lengths

# %%
# Remove any terms from core dict NOT in current model (these will have to be replaced):
for word in inq30:
    if word not in list(model.vocab):
        inq30.remove(word)
        print("NOT FOUND IN CORE DICT, REMOVING:\t" + word)

count = 0
for word in inquiry_fin:
    if word not in list(model.vocab):
        inquiry_fin.remove(word)
        count += 1
        #print("NOT FOUND in FULL DICT, REMOVING:\t" + word)

# Loop twice to catch any remaining OOV terms:
for word in inquiry_fin:
    if word not in list(model.vocab):
        inquiry_fin.remove(word)
        count += 1
        
print("Removed " + str(count) + " out-of-vocabulary terms from full dictionary.")
# Out:
# Removed 2 out-of-vocabulary terms from full dictionary.

# %%
print("Length of original dict: ", len(inq30))
print("Coherence of original dict: ", str(dict_cohere(inq30, model)))

print("Length of extended dict: ", len(inquiry_fin))
print("Coherence of extended dict: ", str(dict_cohere(inquiry_fin, model)))
# Out:
# Length of original dict:  30
# Coherence of original dict:  0.694298374917772
# Length of extended dict:  498
# Coherence of extended dict:  0.5983296162685932

# %%
# Use random adds to create a few dicts of different lengths from max length of 500:

print("TESTING DIFFERENT LENGTHS USING RANDOM ADDITIONS:\n")
# TO DO: Write function expand_dict() above to automate this

inqlist = []; inqlist = inq30 # initialize placeholder for each growing dict
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq30, model)))
print()

# 40 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq30, inquiry_fin) if term in list(model.vocab)], size=10, replace=False))
inq40 = []; inq40 = inqlist
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq40, model)))
print()

# 50 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq40, inquiry_fin) if term in list(model.vocab)], size=10, replace=False))
inq50 = inqlist
#print("50 terms: \n", [term for term in inq50])
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq50, model)))
print()

# 75 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq50, inquiry_fin) if term in list(model.vocab)], size=25, replace=False))
inq75 = inqlist
#print("75 terms: \n", [term for term in inq75])
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq75, model)))
print()

# 100 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq75, inquiry_fin) if term in list(model.vocab)], size=25, replace=False))
inq100 = inqlist
#print("100 terms: \n", [term for term in inq100])
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq100, model)))
print()

# 200 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq100, inquiry_fin) if term in list(model.vocab)], size=100, replace=False))
inq200 = inqlist
#print("200 terms: \n", [term for term in inq200])
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq200, model)))
print()

# 300 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq200, inquiry_fin) if term in list(model.vocab)], size=100, replace=False))
inq300 = inqlist
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq300, model)))
print()

# 400 terms:
inqlist.extend(np.random.choice([term for term in filter(lambda x: x not in inq300, inquiry_fin) if term in list(model.vocab)], size=100, replace=False))
inq400 = inqlist
print(str(len(inqlist)) + "-term dict has this much coherence:", str(dict_cohere(inq400, model)))
print()

print("500-term dict has this much coherence:", str(dict_cohere(inquiry_fin, model)))
# Out:
# TESTING DIFFERENT LENGTHS USING RANDOM ADDITIONS:
#
# 30-term dict has this much coherence: 0.694298374917772
#
# 40-term dict has this much coherence: 0.6336066746711732
#
# 50-term dict has this much coherence: 0.6267515384674072
#
# 75-term dict has this much coherence: 0.6087374311659071
#
# 100-term dict has this much coherence: 0.6085788740158081
#
# 200-term dict has this much coherence: 0.6090105971336366
#
# 300-term dict has this much coherence: 0.6010488780551487
#
# 400-term dict has this much coherence: 0.6033310662269595
#
# 500-term dict has this much coherence: 0.5983296162685932

# %%
# TO DO: Fix this

# Use removal of least similar word vectors to create a few dicts of different lengths from max length of 500:
lens_list = [500, 400, 300, 200, 100, 75, 60, 50, 40, 30] # Define desired dict lengths

# Load full 500-term dicts:
inquiry_fin = [elem.strip('\n') for elem in load_list('data/inquiry.txt')]

# Remove any terms from core dict NOT in current model (these will have to be replaced):
for word in inq30:
    if word not in list(model.vocab):
        inq30.remove(word)
        print("NOT FOUND IN CORE DICT, REMOVING:\t" + word)
print()

count = 0
for word in inquiry_fin:
    if word not in list(model.vocab):
        inquiry_fin.remove(word)
        count += 1
        #print("NOT FOUND in FULL DICT, REMOVING:\t" + word)
        
for word in inquiry_fin:
    if word not in list(model.vocab):
        inquiry_fin.remove(word)
        count += 1
    
print("Removed " + str(count) + " out-of-vocabulary terms from full dictionary.")

print('TESTING DICT LENGTHS BY REMOVING LEAST SIMILAR WORD VECTORS:\n')

for dictlen in lens_list: 
    inqdict = [],
    
    inqdict = focus_dict(inquiry_fin, inq30, dictlen, model)
    
    print(str(dictlen) + "-term dicts have this much coherence:", str(dict_cohere(inqdict, model)))
    print()
# Out:
# Removed 2 out-of-vocabulary terms from full dictionary.
# TESTING DICT LENGTHS BY REMOVING LEAST SIMILAR WORD VECTORS:
#
# WARNING: Function produced a dictionary of length 498, which is not the specified maximum dict length of 500
# 500-term dicts have this much coherence: 0.5983296162685932
# /opt/conda/lib/python3.6/site-packages/gensim/models/keyedvectors.py:876: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 400-term dicts have this much coherence: 0.6033310662269596
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-55aca80ee596> in <module>
#      33     inqdict = [],
#      34
# ---> 35     inqdict = focus_dict(inquiry_fin, inq30, dictlen, model)
#      36
#      37     print(str(dictlen) + "-term dicts have this much coherence:", str(dict_cohere(inqdict, model)))
#
# <ipython-input-21-df565e6c2a5b> in focus_dict(thisdict, coredict, maxlen, wem_model)
#      16
#      17     while extend_count < core_count: # Remove terms until length = maxlen - number of core terms removed (to offset those core terms that will be added back in later in this script)
# ---> 18         badvar = model.doesnt_match(thisdict) # Find least matching term
#      19         thisdict.remove(badvar) # Remove that least focal term, to focus dict
#      20         extend_count += 1 # Keep track of # non-core terms added
#
# /opt/conda/lib/python3.6/site-packages/gensim/models/keyedvectors.py in doesnt_match(self, words)
#     873             logger.warning("vectors for words %s are not present in the model, ignoring these words", ignored_words)
#     874         if not used_words:
# --> 875             raise ValueError("cannot select a word from an empty list")
#     876         vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
#     877         mean = matutils.unitvec(vectors.mean(axis=0)).astype(REAL)
#
# ValueError: cannot select a word from an empty list

# %% [markdown]
# ## Surprising trends in analyzing how dictionary length affects inter-dictionary opposition and within-dictionary coherence (from this and other analyses):
# ### Greater lengths make for more within-dictionary coherence, but less across-dictionary opposition.
# ### Trimming word vectors randomly yields dictionaries that are less coherent and more opposing than does trimming those word vectors least similar to the others in the dictionary.
# #### Caveat: The above patterns assume (perhaps consequentially, perhaps not) that as we trim dictionaries, we are keeping a small, core list of concepts (here, 30) intact within each dictionary. The size of this core may influence the above dynamics, as may the relative size of the total dictionary compared to the core list.
